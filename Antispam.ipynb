# %% [markdown]
# # ** Описание **

# %%
from __future__ import division

import base64
import csv
import gzip
import zlib
import mmh3
import xgboost as xgb
import numpy as np
from urlparse import urlparse


from collections import namedtuple

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
TRACE_NUM = 1000
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%H:%M:%S')

def trace(items_num, trace_num=TRACE_NUM):
    if items_num % trace_num == 0: logging.info("Complete items %05d" % items_num)

# %%
def to_utf8(text):
    if isinstance(text, unicode): text = text.encode('utf8')
    return text

def convert2unicode(f):
    def tmp(text):
        if not isinstance(text, unicode): text = text.decode('utf8')
        return f(text)
    return tmp

def convert2lower(f):
    def tmp(text):        
        return f(text.lower())
    return tmp

#P.S. Декораторы могут усложнять отладку, так что от них вполне можно отказаться и воспользоваться copy-paste

# %%
from HTMLParser import HTMLParser
import re

###Извлечение текста из title можно вписать сюда

class TextHTMLParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self._text = []
        self._title = ""
        self._in_title = False
        self._urls = []
        self._imgs = 0

    def handle_data(self, data):
        text = data.strip()
        if len(text) > 0:
            text = re.sub('[ \t\r\n]+', ' ', text)
            self._text.append(text + ' ')
                

    def handle_starttag(self, tag, attrs):
        if tag == 'p':
            self._text.append('\n\n')
        elif tag == 'br':
            self._text.append('\n')
        elif tag == 'title':
            self._in_title = True
        elif tag == 'img':
            self._imgs += 1
        elif tag == "a":
            for name, value in attrs:
                if name == "href":
                    self._urls.append(value)

    def handle_startendtag(self, tag, attrs):
        if tag == 'br':
            self._text.append('\n\n')
        elif tag == 'title':
            self._in_title = False

    def text(self):
        return ''.join(self._text).strip()


@convert2unicode
def html2text_parser(text):
    parser = TextHTMLParser()
    parser.feed(text)
    return parser.text(), parser._urls, parser._imgs

# %%
def html2text_bs(raw_html):
    from bs4 import BeautifulSoup
    """
    Тут производится извлечения из html текста
    """
    soup = BeautifulSoup(raw_html, "html.parser")
    [s.extract() for s in soup(['script', 'style'])]
    return soup.get_text()

def html2text_bs_visible(raw_html):
    from bs4 import BeautifulSoup
    """
    Тут производится извлечения из html текста, который видим пользователю
    """
    soup = BeautifulSoup(raw_html, "html.parser")    
    [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
    return soup.get_text()

def html2text_boilerpipe(raw_html):
    import boilerpipe
    """
    еще одна библиотека очень хорошо извлекающая именно видимый пользователю текст,
    но она завязана на java
    """
    pass

# %%
#html2text = html2text_bs
html2text = html2text_parser

# %%
@convert2lower
@convert2unicode
def easy_tokenizer(text):
    word = unicode()
    for symbol in text:
        if symbol.isalnum(): word += symbol
        elif word:
            yield word
            word = unicode()
    if word: yield word

PYMORPHY_CACHE = {}
MORPH = None
#hint, чтобы установка pymorphy2 не была бы обязательной
def get_lemmatizer():
    import pymorphy2
    global MORPH
    if MORPH is None: MORPH = pymorphy2.MorphAnalyzer()
    return MORPH

@convert2lower
@convert2unicode
def pymorphy_tokenizer(text):
    global PYMORPHY_CACHE
    for word in easy_tokenizer(text):
        word_hash = mmh3.hash(word.encode("utf-8"))
        if word_hash not in PYMORPHY_CACHE:
            PYMORPHY_CACHE[word_hash] = get_lemmatizer().parse(word)[0].normal_form
        yield PYMORPHY_CACHE[word_hash]

# %%
def html2word(raw_html, to_text=html2text, tokenizer=easy_tokenizer):
    words, urls, imgs = to_text(raw_html)
    return tokenizer(words.lower()), urls, imgs

# %%
def safe_divide(a, b):
    if a == 0: return 0.0
    elif b == 0: return 0.0
    else: return a/b

def calculate_metrics(predictions, threshold):    
    """
    Функция подсчета метрик
    Параметры
    predictions - ранки по документам
    threshold  - порог для метрик
    """
    true_positive = 0
    false_positive = 0
    true_negative = 0
    false_negative = 0
    for (url_id, mark, url, prediction) in predictions:        
        mark_predict = prediction > threshold

        if mark_predict:                     
            if mark_predict == mark: true_positive += 1
            else: false_positive += 1                    
        else:                     
            if  mark_predict == mark: true_negative += 1
            else: false_negative += 1

    class_prec  = safe_divide(true_positive, true_positive + false_positive)
    class_recall = safe_divide(true_positive, true_positive + false_negative)
        
    class_F1 = safe_divide(2 * class_prec * class_recall, class_prec + class_recall)
    
    
    not_class_prec = safe_divide(true_negative, true_negative + false_negative)
    not_class_recall = safe_divide(true_negative, true_negative + false_positive)
    
    not_class_F1 = safe_divide(2 * not_class_prec * not_class_recall, not_class_prec + not_class_recall)
    
    return ( (class_prec, class_recall, class_F1), (not_class_prec, not_class_recall, not_class_F1) )

def arange(start, stop, step):
    cur_value = start
    while True:
        if cur_value > stop: break
        yield cur_value
        cur_value += step

def plot_results(docs, min_threshold=-1, max_threshold=1, step=0.1, trace=False):
    x = []
    y_p = []
    y_n = []
    docs_predictions = classifier.predict_all(docs)
    for threshold in arange(min_threshold, max_threshold, step):
        r = calculate_metrics(docs_predictions, threshold)
        x.append(threshold)
        y_p.append(r[0])
        y_n.append(r[1])        
        if trace: 
            print 'threshold %s' % threshold
            print '\tclass_prec %s, class_recall %s, class_F1 %s' % r[0]
            print '\tnot_class_prec %s, not_class_recall %s, not_class_F1 %s' % r[1]
            print '\t\tMacroF1Mesure %s' % ((r[0][2] + r[1][2])/2)
    plot_stats(x, y_p, "Class Result")
    plot_stats(x, y_n, "Not class Result")    


def plot_stats(x, y, title):
    plt.figure(figsize=(10, 5))

    prec, = plt.plot( x, 
                     [k[0] for k in y], "r", label='Precision', 
                     linewidth=1)
    accur, = plt.plot( x, 
                      [k[1] for k in y], "b", label='Recall',
                      linewidth=1)
    f1, =    plt.plot( x, 
                      [k[2] for k in y], "g", label='F1',
                      linewidth=1)
    plt.grid(True)
    plt.legend(handles=[prec, accur, f1])
    plt.title(title)
    plt.show()

# %%
def calc_features(url, html_data):
    compression_level = len(zlib.compress(html_data)) / len(html_data) 

    return [0, compression_level, 0, 0, 0]

# %%
DocItem = namedtuple('DocItem', ['doc_id', 'is_spam', 'url', 'features', 'words', 'urls', 'imgs'])

def load_csv(input_file_name, calc_features_f):    
    """
    Загружаем данные и извлекаем на лету признаки
    Сам контент не сохраняется, чтобы уменьшить потребление памяти - чтобы
    можно было запускать даже на ноутбуках в классе
    """
    
    with gzip.open(input_file_name) if input_file_name.endswith('gz') else open(input_file_name)  as input_file:            
        headers = input_file.readline()
        
        for i, line in enumerate(input_file):
            trace(i)
            parts = line.strip().split('\t')
            url_id = int(parts[0])                                        
            mark = bool(int(parts[1]))                    
            url = parts[2]
            pageInb64 = parts[3]
            html_data = base64.b64decode(pageInb64)
            features = calc_features_f(url, html_data)
            
            words, urls, imgs = html2word(html_data)
            urls.append(url)
            urls.append(url)
            proc_urls = []
            for u in urls:
                if u is None:
                    continue
                tmp = urlparse(u).hostname
                if tmp is not None:
                    proc_urls.append(tmp)
            yield DocItem(url_id, mark, url, features, list(words), list(proc_urls), imgs)    
            trace(i)
                
        trace(i, 1)

# %%
TRAIN_DATA_FILE  = 'kaggle/kaggle_train_data_tab.csv.gz'
# TRAIN_DATA_FILE  = 'kaggle/kaggle_train_data_tab_300.csv.gz'

train_docs = list(load_csv(TRAIN_DATA_FILE, calc_features))
# Out:
# 10:47:36 INFO:Complete items 00000
# 10:47:37 INFO:Complete items 00000
# 10:48:02 INFO:Complete items 01000
# 10:48:02 INFO:Complete items 01000
# 10:48:23 INFO:Complete items 02000
# 10:48:23 INFO:Complete items 02000
# 10:48:45 INFO:Complete items 03000
# 10:48:45 INFO:Complete items 03000
# 10:49:06 INFO:Complete items 04000
# 10:49:06 INFO:Complete items 04000
# 10:49:29 INFO:Complete items 05000
# 10:49:29 INFO:Complete items 05000
# 10:49:52 INFO:Complete items 06000
# 10:49:52 INFO:Complete items 06000
# 10:50:15 INFO:Complete items 07000
# 10:50:15 INFO:Complete items 07000
# 10:50:16 INFO:Complete items 07043

# %%
class Classifier:
    
    def __init__(self):
        self.p_h = {}
        self.p_s = {}
        self.p_h_url = {}
        self.p_s_url = {}
        self.spam_url = []
        self.h = 0
        self.ham_amount = 0
        self.header_weight = 1
        

    def predict(self, doc):
        import math
        spam_n = 1
        ham_n = 1
        some_sum = 0

        for word in doc.words:
            if word not in self.p_s or word not in self.p_h:
                continue
            some_sum += math.log(self.p_s[word] / self.p_h[word])

        return some_sum   
    
    def predict_url(self, doc):
        import math
        spam_n = 1
        ham_n = 1
        some_sum = 0

        for word in doc.urls:
            if word not in self.p_s_url or word not in self.p_h_url:
                continue
            some_sum += math.log(self.p_s_url[word] / self.p_h_url[word])

        return some_sum   
    
    def predict_all(self, docs):
        res = []
        other = []
        for doc_num, doc in enumerate(docs):
            doc.features[0] = self.predict(doc)
            doc.features[2] = self.predict_url(doc)
            doc.features[3] = len(doc.urls) / len(doc.words)
            doc.features[4] = doc.imgs / len(doc.words)
                    
            trace(doc_num)
            res.append(doc.features)
            other.append((doc.doc_id, doc.is_spam, doc.url))
            trace(doc_num)
            
        dtrain = xgb.DMatrix(np.array(res))
        prediction = self.bst.predict(dtrain) 
        
        i = 0
        result = []
        for (idd, iss, url) in other:
            p = prediction[i]
            result.append( (idd, iss, url, p) )
            i += 1
            trace(doc_num)
        return result
    
    def train(self, docs):    
        ham_amount = 0
        spam_amount = 0
        in_ham = {}
        in_spam = {}
        
        ham_url_amount = 0
        spam_url_amount = 0
        in_ham_url = {}
        in_spam_url = {}
        
        for doc_num, doc in enumerate(docs):
            if doc.is_spam:
                self.spam_url.append(doc.url)
                spam_amount += len(doc.words)
                for word in doc.words:
                    in_spam[word] = in_spam.get(word, 0) + 1
                spam_url_amount += len(doc.urls)
                for word in doc.urls:
                    in_spam_url[word] = in_spam_url.get(word, 0) + 1
            else:
                self.ham_amount += 1
                ham_amount += len(doc.words)
                for word in doc.words:
                    in_ham[word] = in_ham.get(word, 0) + 1
                ham_url_amount += len(doc.urls)
                for word in doc.urls:
                    in_ham_url[word] = in_ham_url.get(word, 0) + 1

        for k, v in in_ham.items():
            self.p_h[k] = v / ham_amount

        for k, v in in_spam.items():
            self.p_s[k] = v / spam_amount

        for k, v in in_ham_url.items():
            self.p_h_url[k] = v / ham_url_amount

        for k, v in in_spam.items():
            self.p_s_url[k] = v / spam_url_amount
            
        for doc_num, doc in enumerate(docs):
            doc.features[0] = self.predict(doc)
            doc.features[2] = self.predict_url(doc)
            doc.features[3] = len(doc.urls) / len(doc.words)
            doc.features[4] = doc.imgs / len(doc.words)
            
            trace(doc_num)
              
        features = []
        labels = []
        weights = []
        spam_amount = len(self.spam_url)
        
        for doc_num, doc in enumerate(docs):
            if not doc.is_spam:
                weights.append(spam_amount / (spam_amount + self.ham_amount))
            else:
                weights.append(self.ham_amount / (spam_amount + self.ham_amount))
            features.append(doc.features)
            labels.append(doc.is_spam)
            trace(doc_num)
            
        import numpy as np
        
        features = np.array(features)
        labels = np.array(labels)
            
        param = {'max_depth':3, 'eta':0.01, 'silent':1, 'objective':'binary:logistic', 'nthread':4}
        dtrain = xgb.DMatrix(features, label=labels, weight=weights)
        
        watchlist  = [(dtrain,'train')]
        num_round = 1000
        self.bst = xgb.train(param, dtrain, num_round, watchlist)
        
        trace(doc_num, 1)

# %%
classifier = Classifier()

# %%
classifier.train(train_docs)
# Out:
# 11:15:33 INFO:Complete items 00000
# 11:15:35 INFO:Complete items 01000
# 11:15:36 INFO:Complete items 02000
# 11:15:37 INFO:Complete items 03000
# 11:15:39 INFO:Complete items 04000
# 11:15:41 INFO:Complete items 05000
# 11:15:42 INFO:Complete items 06000
# 11:15:44 INFO:Complete items 07000
# 11:15:44 INFO:Complete items 00000
# 11:15:44 INFO:Complete items 01000
# 11:15:44 INFO:Complete items 02000
# 11:15:44 INFO:Complete items 03000
# 11:15:44 INFO:Complete items 04000
# 11:15:44 INFO:Complete items 05000
# 11:15:44 INFO:Complete items 06000
# 11:15:44 INFO:Complete items 07000
# [0]	train-error:0.034753
# [1]	train-error:0.034753
# [2]	train-error:0.034753
# [3]	train-error:0.034753
# [4]	train-error:0.034753
# [5]	train-error:0.034753
# [6]	train-error:0.034753
# [7]	train-error:0.034753
# [8]	train-error:0.034753
# [9]	train-error:0.034753
# [10]	train-error:0.034753
# [11]	train-error:0.034753
# [12]	train-error:0.034753
# [13]	train-error:0.034753
# [14]	train-error:0.032636
# [15]	train-error:0.032636
# [16]	train-error:0.032636
# [17]	train-error:0.029837
# [18]	train-error:0.029837
# [19]	train-error:0.029837
# [20]	train-error:0.029837
# [21]	train-error:0.029837
# [22]	train-error:0.029837
# [23]	train-error:0.029837
# [24]	train-error:0.029837
# [25]	train-error:0.029837
# [26]	train-error:0.029837
# [27]	train-error:0.029837
# [28]	train-error:0.029837
# [29]	train-error:0.029837
# [30]	train-error:0.029837
# [31]	train-error:0.029837
# [32]	train-error:0.029837
# [33]	train-error:0.029837
# [34]	train-error:0.029837
# [35]	train-error:0.029837
# [36]	train-error:0.029837
# [37]	train-error:0.029837
# [38]	train-error:0.029837
# [39]	train-error:0.029837
# [40]	train-error:0.029837
# [41]	train-error:0.029837
# [42]	train-error:0.029837
# [43]	train-error:0.029837
# [44]	train-error:0.029837
# [45]	train-error:0.029837
# [46]	train-error:0.029837
# [47]	train-error:0.029837
# [48]	train-error:0.029837
# [49]	train-error:0.029837
# [50]	train-error:0.029837
# [51]	train-error:0.029837
# [52]	train-error:0.029837
# [53]	train-error:0.029959
# [54]	train-error:0.029959
# [55]	train-error:0.029959
# [56]	train-error:0.029959
# [57]	train-error:0.029959
# [58]	train-error:0.029959
# [59]	train-error:0.02974
# [60]	train-error:0.029569
# [61]	train-error:0.029569
# [62]	train-error:0.029569
# [63]	train-error:0.029569
# [64]	train-error:0.029569
# [65]	train-error:0.029569
# [66]	train-error:0.029569
# [67]	train-error:0.029569
# [68]	train-error:0.029813
# [69]	train-error:0.029813
# [70]	train-error:0.029813
# [71]	train-error:0.029642
# [72]	train-error:0.029642
# [73]	train-error:0.029642
# [74]	train-error:0.029642
# [75]	train-error:0.029642
# [76]	train-error:0.029642
# [77]	train-error:0.029642
# [78]	train-error:0.029034
# [79]	train-error:0.029642
# [80]	train-error:0.029642
# [81]	train-error:0.029034
# [82]	train-error:0.029034
# [83]	train-error:0.029034
# [84]	train-error:0.029034
# [85]	train-error:0.029034
# [86]	train-error:0.029034
# [87]	train-error:0.029034
# [88]	train-error:0.029034
# [89]	train-error:0.029034
# [90]	train-error:0.029034
# [91]	train-error:0.029034
# [92]	train-error:0.029107
# [93]	train-error:0.029034
# [94]	train-error:0.029107
# [95]	train-error:0.029107
# [96]	train-error:0.02918
# [97]	train-error:0.02918
# [98]	train-error:0.02918
# [99]	train-error:0.02918
# [100]	train-error:0.02918
# [101]	train-error:0.02918
# [102]	train-error:0.02918
# [103]	train-error:0.02918
# [104]	train-error:0.02918
# [105]	train-error:0.02918
# [106]	train-error:0.02918
# [107]	train-error:0.02918
# [108]	train-error:0.02918
# [109]	train-error:0.02918
# [110]	train-error:0.02918
# [111]	train-error:0.02918
# [112]	train-error:0.02918
# [113]	train-error:0.02918
# [114]	train-error:0.02918
# [115]	train-error:0.02918
# [116]	train-error:0.02918
# [117]	train-error:0.02918
# [118]	train-error:0.02918
# [119]	train-error:0.02918
# [120]	train-error:0.02918
# [121]	train-error:0.02918
# [122]	train-error:0.02918
# [123]	train-error:0.02918
# [124]	train-error:0.02918
# [125]	train-error:0.02918
# [126]	train-error:0.02918
# [127]	train-error:0.02918
# [128]	train-error:0.02918
# [129]	train-error:0.02918
# [130]	train-error:0.02918
# [131]	train-error:0.02918
# [132]	train-error:0.02918
# [133]	train-error:0.02918
# [134]	train-error:0.02918
# [135]	train-error:0.02918
# [136]	train-error:0.02918
# [137]	train-error:0.02918
# [138]	train-error:0.02918
# [139]	train-error:0.029009
# [140]	train-error:0.029009
# [141]	train-error:0.029009
# [142]	train-error:0.029009
# [143]	train-error:0.029009
# [144]	train-error:0.028888
# [145]	train-error:0.028888
# [146]	train-error:0.028888
# [147]	train-error:0.028888
# [148]	train-error:0.028888
# [149]	train-error:0.028888
# [150]	train-error:0.028888
# [151]	train-error:0.028888
# [152]	train-error:0.028888
# [153]	train-error:0.028888
# [154]	train-error:0.028547
# [155]	train-error:0.028547
# [156]	train-error:0.028547
# [157]	train-error:0.028425
# [158]	train-error:0.028425
# [159]	train-error:0.028425
# [160]	train-error:0.028425
# [161]	train-error:0.028425
# [162]	train-error:0.028425
# [163]	train-error:0.028425
# [164]	train-error:0.028425
# [165]	train-error:0.028425
# [166]	train-error:0.028425
# [167]	train-error:0.028425
# [168]	train-error:0.028425
# [169]	train-error:0.028425
# [170]	train-error:0.028425
# [171]	train-error:0.028425
# [172]	train-error:0.028425
# [173]	train-error:0.028425
# [174]	train-error:0.028425
# [175]	train-error:0.028425
# [176]	train-error:0.028425
# [177]	train-error:0.028425
# [178]	train-error:0.028425
# [179]	train-error:0.02918
# [180]	train-error:0.02918
# [181]	train-error:0.02918
# [182]	train-error:0.02918
# [183]	train-error:0.02918
# [184]	train-error:0.02918
# [185]	train-error:0.029009
# [186]	train-error:0.029009
# [187]	train-error:0.029009
# [188]	train-error:0.029009
# [189]	train-error:0.029009
# [190]	train-error:0.029009
# [191]	train-error:0.029009
# [192]	train-error:0.029009
# [193]	train-error:0.029009
# [194]	train-error:0.029009
# [195]	train-error:0.028912
# [196]	train-error:0.028912
# [197]	train-error:0.028912
# [198]	train-error:0.028912
# [199]	train-error:0.02879
# [200]	train-error:0.02879
# [201]	train-error:0.02879
# [202]	train-error:0.02879
# [203]	train-error:0.02879
# [204]	train-error:0.02879
# [205]	train-error:0.02879
# [206]	train-error:0.02879
# [207]	train-error:0.02879
# [208]	train-error:0.02879
# [209]	train-error:0.02879
# [210]	train-error:0.02879
# [211]	train-error:0.02879
# [212]	train-error:0.02879
# [213]	train-error:0.02879
# [214]	train-error:0.02879
# [215]	train-error:0.02879
# [216]	train-error:0.02879
# [217]	train-error:0.02879
# [218]	train-error:0.02862
# [219]	train-error:0.02862
# [220]	train-error:0.02862
# [221]	train-error:0.02862
# [222]	train-error:0.02862
# [223]	train-error:0.02862
# [224]	train-error:0.02862
# [225]	train-error:0.02862
# [226]	train-error:0.02862
# [227]	train-error:0.02845
# [228]	train-error:0.02845
# [229]	train-error:0.02845
# [230]	train-error:0.02845
# [231]	train-error:0.02845
# [232]	train-error:0.02845
# [233]	train-error:0.02845
# [234]	train-error:0.02845
# [235]	train-error:0.02845
# [236]	train-error:0.02845
# [237]	train-error:0.02845
# [238]	train-error:0.02845
# [239]	train-error:0.02845
# [240]	train-error:0.02845
# [241]	train-error:0.02845
# [242]	train-error:0.02845
# [243]	train-error:0.02845
# [244]	train-error:0.02845
# [245]	train-error:0.02845
# [246]	train-error:0.02845
# [247]	train-error:0.02845
# [248]	train-error:0.02845
# [249]	train-error:0.02845
# [250]	train-error:0.02845
# [251]	train-error:0.028571
# [252]	train-error:0.028571
# [253]	train-error:0.028571
# [254]	train-error:0.028571
# [255]	train-error:0.028571
# [256]	train-error:0.028571
# [257]	train-error:0.028571
# [258]	train-error:0.028571
# [259]	train-error:0.028571
# [260]	train-error:0.028571
# [261]	train-error:0.028571
# [262]	train-error:0.02845
# [263]	train-error:0.02845
# [264]	train-error:0.02845
# [265]	train-error:0.02845
# [266]	train-error:0.02845
# [267]	train-error:0.02845
# [268]	train-error:0.02845
# [269]	train-error:0.02845
# [270]	train-error:0.02845
# [271]	train-error:0.02845
# [272]	train-error:0.02845
# [273]	train-error:0.02845
# [274]	train-error:0.02845
# [275]	train-error:0.02845
# [276]	train-error:0.02845
# [277]	train-error:0.02845
# [278]	train-error:0.02845
# [279]	train-error:0.02845
# [280]	train-error:0.02845
# [281]	train-error:0.02845
# [282]	train-error:0.02845
# [283]	train-error:0.02845
# [284]	train-error:0.02845
# [285]	train-error:0.02845
# [286]	train-error:0.02845
# [287]	train-error:0.02845
# [288]	train-error:0.02845
# [289]	train-error:0.02845
# [290]	train-error:0.02845
# [291]	train-error:0.02845
# [292]	train-error:0.02845
# [293]	train-error:0.02845
# [294]	train-error:0.02845
# [295]	train-error:0.02845
# [296]	train-error:0.02845
# [297]	train-error:0.02845
# [298]	train-error:0.02845
# [299]	train-error:0.02845
# [300]	train-error:0.02845
# [301]	train-error:0.02845
# [302]	train-error:0.02845
# [303]	train-error:0.02845
# [304]	train-error:0.02845
# [305]	train-error:0.02845
# [306]	train-error:0.02845
# [307]	train-error:0.02845
# [308]	train-error:0.02845
# [309]	train-error:0.02845
# [310]	train-error:0.02845
# [311]	train-error:0.02845
# [312]	train-error:0.02845
# [313]	train-error:0.028328
# [314]	train-error:0.028328
# [315]	train-error:0.028328
# [316]	train-error:0.028328
# [317]	train-error:0.028328
# [318]	train-error:0.028328
# [319]	train-error:0.028328
# [320]	train-error:0.028328
# [321]	train-error:0.028328
# [322]	train-error:0.028328
# [323]	train-error:0.028328
# [324]	train-error:0.028328
# [325]	train-error:0.028328
# [326]	train-error:0.028328
# [327]	train-error:0.028328
# [328]	train-error:0.028328
# [329]	train-error:0.028328
# [330]	train-error:0.028328
# [331]	train-error:0.028328
# [332]	train-error:0.028328
# [333]	train-error:0.028328
# [334]	train-error:0.028328
# [335]	train-error:0.028328
# [336]	train-error:0.028328
# [337]	train-error:0.028328
# [338]	train-error:0.028328
# [339]	train-error:0.028328
# [340]	train-error:0.028328
# [341]	train-error:0.028328
# [342]	train-error:0.028328
# [343]	train-error:0.028328
# [344]	train-error:0.028328
# [345]	train-error:0.028328
# [346]	train-error:0.028328
# [347]	train-error:0.028328
# [348]	train-error:0.028328
# [349]	train-error:0.028328
# [350]	train-error:0.028328
# [351]	train-error:0.028328
# [352]	train-error:0.028328
# [353]	train-error:0.028328
# [354]	train-error:0.028328
# [355]	train-error:0.028328
# [356]	train-error:0.028328
# [357]	train-error:0.028328
# [358]	train-error:0.028328
# [359]	train-error:0.028328
# [360]	train-error:0.028328
# [361]	train-error:0.028328
# [362]	train-error:0.028328
# [363]	train-error:0.028206
# [364]	train-error:0.028206
# [365]	train-error:0.028206
# [366]	train-error:0.028206
# [367]	train-error:0.028206
# [368]	train-error:0.028206
# [369]	train-error:0.028206
# [370]	train-error:0.028206
# [371]	train-error:0.028206
# [372]	train-error:0.028206
# [373]	train-error:0.028206
# [374]	train-error:0.028206
# [375]	train-error:0.028206
# [376]	train-error:0.028206
# [377]	train-error:0.028206
# [378]	train-error:0.028206
# [379]	train-error:0.028206
# [380]	train-error:0.028206
# [381]	train-error:0.028206
# [382]	train-error:0.028206
# [383]	train-error:0.028206
# [384]	train-error:0.028377
# [385]	train-error:0.028377
# [386]	train-error:0.028377
# [387]	train-error:0.028377
# [388]	train-error:0.028377
# [389]	train-error:0.028377
# [390]	train-error:0.028377
# [391]	train-error:0.028377
# [392]	train-error:0.028377
# [393]	train-error:0.028377
# [394]	train-error:0.028377
# [395]	train-error:0.028377
# [396]	train-error:0.028377
# [397]	train-error:0.028377
# [398]	train-error:0.028206
# [399]	train-error:0.028206
# [400]	train-error:0.028206
# [401]	train-error:0.028206
# [402]	train-error:0.028206
# [403]	train-error:0.028206
# [404]	train-error:0.028206
# [405]	train-error:0.028206
# [406]	train-error:0.028206
# [407]	train-error:0.028206
# [408]	train-error:0.028206
# [409]	train-error:0.028206
# [410]	train-error:0.028206
# [411]	train-error:0.028206
# [412]	train-error:0.028206
# [413]	train-error:0.028206
# [414]	train-error:0.028206
# [415]	train-error:0.028206
# [416]	train-error:0.028206
# [417]	train-error:0.028206
# [418]	train-error:0.028206
# [419]	train-error:0.028206
# [420]	train-error:0.028158
# [421]	train-error:0.028158
# [422]	train-error:0.028158
# [423]	train-error:0.028158
# [424]	train-error:0.028158
# [425]	train-error:0.028158
# [426]	train-error:0.028158
# [427]	train-error:0.028036
# [428]	train-error:0.028036
# [429]	train-error:0.028036
# [430]	train-error:0.028036
# [431]	train-error:0.028036
# [432]	train-error:0.028036
# [433]	train-error:0.028036
# [434]	train-error:0.028036
# [435]	train-error:0.028036
# [436]	train-error:0.028036
# [437]	train-error:0.028036
# [438]	train-error:0.028036
# [439]	train-error:0.028036
# [440]	train-error:0.028036
# [441]	train-error:0.028036
# [442]	train-error:0.028036
# [443]	train-error:0.028036
# [444]	train-error:0.028036
# [445]	train-error:0.028036
# [446]	train-error:0.028036
# [447]	train-error:0.028036
# [448]	train-error:0.028036
# [449]	train-error:0.028036
# [450]	train-error:0.028036
# [451]	train-error:0.028036
# [452]	train-error:0.028036
# [453]	train-error:0.028036
# [454]	train-error:0.028036
# [455]	train-error:0.028036
# [456]	train-error:0.028036
# [457]	train-error:0.028036
# [458]	train-error:0.028036
# [459]	train-error:0.028036
# [460]	train-error:0.028036
# [461]	train-error:0.028036
# [462]	train-error:0.028036
# [463]	train-error:0.028036
# [464]	train-error:0.028036
# [465]	train-error:0.028036
# [466]	train-error:0.028036
# [467]	train-error:0.028036
# [468]	train-error:0.028036
# [469]	train-error:0.028036
# [470]	train-error:0.028036
# [471]	train-error:0.028036
# [472]	train-error:0.028036
# [473]	train-error:0.028036
# [474]	train-error:0.028036
# [475]	train-error:0.028036
# [476]	train-error:0.028036
# [477]	train-error:0.028036
# [478]	train-error:0.028036
# [479]	train-error:0.028036
# [480]	train-error:0.028036
# [481]	train-error:0.028036
# [482]	train-error:0.028036
# [483]	train-error:0.028036
# [484]	train-error:0.028036
# [485]	train-error:0.028036
# [486]	train-error:0.028036
# [487]	train-error:0.028036
# [488]	train-error:0.028036
# [489]	train-error:0.028036
# [490]	train-error:0.028036
# [491]	train-error:0.028036
# [492]	train-error:0.028036
# [493]	train-error:0.028036
# [494]	train-error:0.028036
# [495]	train-error:0.028206
# [496]	train-error:0.028036
# [497]	train-error:0.028036
# [498]	train-error:0.028036
# [499]	train-error:0.028036
# [500]	train-error:0.028036
# [501]	train-error:0.028036
# [502]	train-error:0.028036
# [503]	train-error:0.028036
# [504]	train-error:0.028036
# [505]	train-error:0.028036
# [506]	train-error:0.028036
# [507]	train-error:0.028036
# [508]	train-error:0.028036
# [509]	train-error:0.028036
# [510]	train-error:0.028036
# [511]	train-error:0.028036
# [512]	train-error:0.028036
# [513]	train-error:0.028036
# [514]	train-error:0.028036
# [515]	train-error:0.027866
# [516]	train-error:0.027866
# [517]	train-error:0.027866
# [518]	train-error:0.027866
# [519]	train-error:0.027866
# [520]	train-error:0.027866
# [521]	train-error:0.027866
# [522]	train-error:0.027866
# [523]	train-error:0.027866
# [524]	train-error:0.027866
# [525]	train-error:0.027866
# [526]	train-error:0.027866
# [527]	train-error:0.027744
# [528]	train-error:0.027744
# [529]	train-error:0.027744
# [530]	train-error:0.027914
# [531]	train-error:0.027914
# [532]	train-error:0.027914
# [533]	train-error:0.027744
# [534]	train-error:0.027744
# [535]	train-error:0.027914
# [536]	train-error:0.027914
# [537]	train-error:0.027914
# [538]	train-error:0.027914
# [539]	train-error:0.028085
# [540]	train-error:0.028085
# [541]	train-error:0.028085
# [542]	train-error:0.028085
# [543]	train-error:0.028085
# [544]	train-error:0.027963
# [545]	train-error:0.027963
# [546]	train-error:0.028085
# [547]	train-error:0.02772
# [548]	train-error:0.02772
# [549]	train-error:0.02772
# [550]	train-error:0.02772
# [551]	train-error:0.027549
# [552]	train-error:0.027549
# [553]	train-error:0.027671
# [554]	train-error:0.027671
# [555]	train-error:0.027671
# [556]	train-error:0.027671
# [557]	train-error:0.027671
# [558]	train-error:0.027671
# [559]	train-error:0.027671
# [560]	train-error:0.027671
# [561]	train-error:0.027671
# [562]	train-error:0.027671
# [563]	train-error:0.027671
# [564]	train-error:0.027671
# [565]	train-error:0.027671
# [566]	train-error:0.027671
# [567]	train-error:0.027671
# [568]	train-error:0.027671
# [569]	train-error:0.027671
# [570]	train-error:0.027671
# [571]	train-error:0.027501
# [572]	train-error:0.027501
# [573]	train-error:0.027501
# [574]	train-error:0.027501
# [575]	train-error:0.027501
# [576]	train-error:0.027501
# [577]	train-error:0.027501
# [578]	train-error:0.027501
# [579]	train-error:0.027501
# [580]	train-error:0.027501
# [581]	train-error:0.027501
# [582]	train-error:0.027501
# [583]	train-error:0.027501
# [584]	train-error:0.027501
# [585]	train-error:0.027501
# [586]	train-error:0.027501
# [587]	train-error:0.027501
# [588]	train-error:0.027501
# [589]	train-error:0.027501
# [590]	train-error:0.027501
# [591]	train-error:0.027501
# [592]	train-error:0.027501
# [593]	train-error:0.027501
# [594]	train-error:0.027501
# [595]	train-error:0.026649
# [596]	train-error:0.026649
# [597]	train-error:0.026649
# [598]	train-error:0.026649
# [599]	train-error:0.026649
# [600]	train-error:0.026649
# [601]	train-error:0.026649
# [602]	train-error:0.026649
# [603]	train-error:0.026649
# [604]	train-error:0.026649
# [605]	train-error:0.026649
# [606]	train-error:0.026649
# [607]	train-error:0.026649
# [608]	train-error:0.026649
# [609]	train-error:0.026819
# [610]	train-error:0.026819
# [611]	train-error:0.026649
# [612]	train-error:0.026649
# [613]	train-error:0.026649
# [614]	train-error:0.026649
# [615]	train-error:0.026649
# [616]	train-error:0.026649
# [617]	train-error:0.026649
# [618]	train-error:0.026649
# [619]	train-error:0.026649
# [620]	train-error:0.026649
# [621]	train-error:0.026649
# [622]	train-error:0.026649
# [623]	train-error:0.026649
# [624]	train-error:0.026649
# [625]	train-error:0.026649
# [626]	train-error:0.026649
# [627]	train-error:0.026649
# [628]	train-error:0.026649
# [629]	train-error:0.026649
# [630]	train-error:0.026649
# [631]	train-error:0.026649
# [632]	train-error:0.026649
# [633]	train-error:0.026649
# [634]	train-error:0.026649
# [635]	train-error:0.026649
# [636]	train-error:0.026649
# [637]	train-error:0.026649
# [638]	train-error:0.026649
# [639]	train-error:0.026649
# [640]	train-error:0.026649
# [641]	train-error:0.026649
# [642]	train-error:0.026649
# [643]	train-error:0.026649
# [644]	train-error:0.026649
# [645]	train-error:0.026649
# [646]	train-error:0.026649
# [647]	train-error:0.026649
# [648]	train-error:0.026649
# [649]	train-error:0.026649
# [650]	train-error:0.026649
# [651]	train-error:0.026649
# [652]	train-error:0.026649
# [653]	train-error:0.026478
# [654]	train-error:0.026478
# [655]	train-error:0.026478
# [656]	train-error:0.026478
# [657]	train-error:0.026478
# [658]	train-error:0.026478
# [659]	train-error:0.026478
# [660]	train-error:0.026478
# [661]	train-error:0.026478
# [662]	train-error:0.026478
# [663]	train-error:0.026478
# [664]	train-error:0.026478
# [665]	train-error:0.026478
# [666]	train-error:0.026478
# [667]	train-error:0.026478
# [668]	train-error:0.026478
# [669]	train-error:0.026478
# [670]	train-error:0.026478
# [671]	train-error:0.026478
# [672]	train-error:0.026478
# [673]	train-error:0.026478
# [674]	train-error:0.026478
# [675]	train-error:0.026478
# [676]	train-error:0.026478
# [677]	train-error:0.026478
# [678]	train-error:0.026478
# [679]	train-error:0.026478
# [680]	train-error:0.026478
# [681]	train-error:0.026478
# [682]	train-error:0.026478
# [683]	train-error:0.026478
# [684]	train-error:0.026478
# [685]	train-error:0.026478
# [686]	train-error:0.026478
# [687]	train-error:0.026478
# [688]	train-error:0.026478
# [689]	train-error:0.026527
# [690]	train-error:0.026527
# [691]	train-error:0.026527
# [692]	train-error:0.026527
# [693]	train-error:0.026527
# [694]	train-error:0.026527
# [695]	train-error:0.026527
# [696]	train-error:0.026527
# [697]	train-error:0.026527
# [698]	train-error:0.026527
# [699]	train-error:0.026527
# [700]	train-error:0.026527
# [701]	train-error:0.026527
# [702]	train-error:0.026527
# [703]	train-error:0.026527
# [704]	train-error:0.026527
# [705]	train-error:0.026527
# [706]	train-error:0.026527
# [707]	train-error:0.026527
# [708]	train-error:0.026527
# [709]	train-error:0.026527
# [710]	train-error:0.026527
# [711]	train-error:0.026527
# [712]	train-error:0.026527
# [713]	train-error:0.026527
# [714]	train-error:0.026527
# [715]	train-error:0.026527
# [716]	train-error:0.026527
# [717]	train-error:0.026527
# [718]	train-error:0.026527
# [719]	train-error:0.026527
# [720]	train-error:0.026527
# [721]	train-error:0.026527
# [722]	train-error:0.026527
# [723]	train-error:0.026527
# [724]	train-error:0.026527
# [725]	train-error:0.026527
# [726]	train-error:0.026527
# [727]	train-error:0.026527
# [728]	train-error:0.026527
# [729]	train-error:0.026527
# [730]	train-error:0.026527
# [731]	train-error:0.026527
# [732]	train-error:0.026527
# [733]	train-error:0.026527
# [734]	train-error:0.026527
# [735]	train-error:0.026527
# [736]	train-error:0.026527
# [737]	train-error:0.026527
# [738]	train-error:0.026527
# [739]	train-error:0.026527
# [740]	train-error:0.026527
# [741]	train-error:0.026527
# [742]	train-error:0.026527
# [743]	train-error:0.026527
# [744]	train-error:0.026527
# [745]	train-error:0.026527
# [746]	train-error:0.026527
# [747]	train-error:0.026527
# [748]	train-error:0.026527
# [749]	train-error:0.026527
# [750]	train-error:0.026527
# [751]	train-error:0.026649
# [752]	train-error:0.026527
# [753]	train-error:0.026527
# [754]	train-error:0.026527
# [755]	train-error:0.026527
# [756]	train-error:0.026527
# [757]	train-error:0.026527
# [758]	train-error:0.026527
# [759]	train-error:0.026527
# [760]	train-error:0.026405
# [761]	train-error:0.026405
# [762]	train-error:0.026405
# [763]	train-error:0.026454
# [764]	train-error:0.026454
# [765]	train-error:0.026454
# [766]	train-error:0.026454
# [767]	train-error:0.026454
# [768]	train-error:0.026454
# [769]	train-error:0.026454
# [770]	train-error:0.026454
# [771]	train-error:0.026454
# [772]	train-error:0.026454
# [773]	train-error:0.026454
# [774]	train-error:0.026454
# [775]	train-error:0.026454
# [776]	train-error:0.026454
# [777]	train-error:0.026454
# [778]	train-error:0.026454
# [779]	train-error:0.026454
# [780]	train-error:0.026454
# [781]	train-error:0.026454
# [782]	train-error:0.026454
# [783]	train-error:0.026454
# [784]	train-error:0.026454
# [785]	train-error:0.026454
# [786]	train-error:0.026454
# [787]	train-error:0.026454
# [788]	train-error:0.026454
# [789]	train-error:0.026454
# [790]	train-error:0.026454
# [791]	train-error:0.026454
# [792]	train-error:0.026454
# [793]	train-error:0.026454
# [794]	train-error:0.026454
# [795]	train-error:0.026454
# [796]	train-error:0.026454
# [797]	train-error:0.026454
# [798]	train-error:0.026454
# [799]	train-error:0.026454
# [800]	train-error:0.026454
# [801]	train-error:0.026454
# [802]	train-error:0.026454
# [803]	train-error:0.026454
# [804]	train-error:0.026454
# [805]	train-error:0.026454
# [806]	train-error:0.026454
# [807]	train-error:0.026454
# [808]	train-error:0.026454
# [809]	train-error:0.026454
# [810]	train-error:0.026454
# [811]	train-error:0.026454
# [812]	train-error:0.026454
# [813]	train-error:0.026454
# [814]	train-error:0.026454
# [815]	train-error:0.026454
# [816]	train-error:0.026454
# [817]	train-error:0.026454
# [818]	train-error:0.026454
# [819]	train-error:0.026454
# [820]	train-error:0.026454
# [821]	train-error:0.026454
# [822]	train-error:0.026454
# [823]	train-error:0.026454
# [824]	train-error:0.026454
# [825]	train-error:0.026454
# [826]	train-error:0.026454
# [827]	train-error:0.026454
# [828]	train-error:0.026454
# [829]	train-error:0.026454
# [830]	train-error:0.026454
# [831]	train-error:0.026454
# [832]	train-error:0.026454
# [833]	train-error:0.026454
# [834]	train-error:0.026454
# [835]	train-error:0.026454
# [836]	train-error:0.026454
# [837]	train-error:0.026454
# [838]	train-error:0.026454
# [839]	train-error:0.026454
# [840]	train-error:0.026454
# [841]	train-error:0.026454
# [842]	train-error:0.026454
# [843]	train-error:0.026454
# [844]	train-error:0.026454
# [845]	train-error:0.026454
# [846]	train-error:0.026454
# [847]	train-error:0.026454
# [848]	train-error:0.026454
# [849]	train-error:0.026454
# [850]	train-error:0.026454
# [851]	train-error:0.026454
# [852]	train-error:0.026454
# [853]	train-error:0.026454
# [854]	train-error:0.026454
# [855]	train-error:0.026454
# [856]	train-error:0.026454
# [857]	train-error:0.026624
# [858]	train-error:0.026624
# [859]	train-error:0.026624
# [860]	train-error:0.026624
# [861]	train-error:0.026624
# [862]	train-error:0.026624
# [863]	train-error:0.026624
# [864]	train-error:0.026624
# [865]	train-error:0.026624
# [866]	train-error:0.026624
# [867]	train-error:0.026624
# [868]	train-error:0.026624
# [869]	train-error:0.026454
# [870]	train-error:0.026454
# [871]	train-error:0.026454
# [872]	train-error:0.026454
# [873]	train-error:0.026454
# [874]	train-error:0.026332
# [875]	train-error:0.026332
# [876]	train-error:0.026454
# [877]	train-error:0.026332
# [878]	train-error:0.026332
# [879]	train-error:0.026332
# [880]	train-error:0.026332
# [881]	train-error:0.026332
# [882]	train-error:0.026332
# [883]	train-error:0.026332
# [884]	train-error:0.026332
# [885]	train-error:0.026332
# [886]	train-error:0.026211
# [887]	train-error:0.026211
# [888]	train-error:0.026211
# [889]	train-error:0.026211
# [890]	train-error:0.026211
# [891]	train-error:0.026211
# [892]	train-error:0.026211
# [893]	train-error:0.026211
# [894]	train-error:0.026211
# [895]	train-error:0.026211
# [896]	train-error:0.026211
# [897]	train-error:0.026211
# [898]	train-error:0.026211
# [899]	train-error:0.026211
# [900]	train-error:0.026211
# [901]	train-error:0.026211
# [902]	train-error:0.026211
# [903]	train-error:0.026211
# [904]	train-error:0.026211
# [905]	train-error:0.026211
# [906]	train-error:0.026211
# [907]	train-error:0.026211
# [908]	train-error:0.026211
# [909]	train-error:0.026211
# [910]	train-error:0.026211
# [911]	train-error:0.026211
# [912]	train-error:0.026211
# [913]	train-error:0.026211
# [914]	train-error:0.026211
# [915]	train-error:0.026211
# [916]	train-error:0.026211
# [917]	train-error:0.026211
# [918]	train-error:0.026211
# [919]	train-error:0.026211
# [920]	train-error:0.026211
# [921]	train-error:0.026211
# [922]	train-error:0.026211
# [923]	train-error:0.02604
# [924]	train-error:0.02604
# [925]	train-error:0.02604
# [926]	train-error:0.02604
# [927]	train-error:0.02604
# [928]	train-error:0.02604
# [929]	train-error:0.02604
# [930]	train-error:0.02604
# [931]	train-error:0.02604
# [932]	train-error:0.02604
# [933]	train-error:0.02604
# [934]	train-error:0.02604
# [935]	train-error:0.02604
# [936]	train-error:0.02604
# [937]	train-error:0.02604
# [938]	train-error:0.02604
# [939]	train-error:0.02604
# [940]	train-error:0.026089
# [941]	train-error:0.026089
# [942]	train-error:0.026211
# [943]	train-error:0.026089
# [944]	train-error:0.026089
# [945]	train-error:0.026089
# [946]	train-error:0.026211
# [947]	train-error:0.02604
# [948]	train-error:0.025797
# [949]	train-error:0.025797
# [950]	train-error:0.026016
# [951]	train-error:0.025846
# [952]	train-error:0.026016
# [953]	train-error:0.025967
# [954]	train-error:0.026138
# [955]	train-error:0.026138
# [956]	train-error:0.025846
# [957]	train-error:0.025846
# [958]	train-error:0.025846
# [959]	train-error:0.025846
# [960]	train-error:0.025846
# [961]	train-error:0.025846
# [962]	train-error:0.025846
# [963]	train-error:0.025846
# [964]	train-error:0.025846
# [965]	train-error:0.025846
# [966]	train-error:0.025846
# [967]	train-error:0.025846
# [968]	train-error:0.025846
# [969]	train-error:0.025846
# [970]	train-error:0.025846
# [971]	train-error:0.025846
# [972]	train-error:0.025846
# [973]	train-error:0.025846
# [974]	train-error:0.025846
# [975]	train-error:0.025846
# [976]	train-error:0.025846
# [977]	train-error:0.025846
# [978]	train-error:0.025846
# [979]	train-error:0.025846
# [980]	train-error:0.025846
# [981]	train-error:0.025846
# [982]	train-error:0.025846
# [983]	train-error:0.025846
# [984]	train-error:0.025846
# [985]	train-error:0.025846
# [986]	train-error:0.025846
# [987]	train-error:0.025846
# [988]	train-error:0.025846
# [989]	train-error:0.025846
# [990]	train-error:0.025846
# [991]	train-error:0.025846
# [992]	train-error:0.025846
# [993]	train-error:0.025846
# [994]	train-error:0.025846
# [995]	train-error:0.025846
# [996]	train-error:0.025846
# [997]	train-error:0.025846
# [998]	train-error:0.025846
# [999]	train-error:0.025846
# 11:16:16 INFO:Complete items 07043

# %%
plot_results(train_docs, min_threshold=0, max_threshold=1, step=0.001, trace=1)
# Out:
# 11:16:16 INFO:Complete items 00000
# 11:16:16 INFO:Complete items 00000
# 11:16:18 INFO:Complete items 01000
# 11:16:18 INFO:Complete items 01000
# 11:16:19 INFO:Complete items 02000
# 11:16:19 INFO:Complete items 02000
# 11:16:20 INFO:Complete items 03000
# 11:16:20 INFO:Complete items 03000
# 11:16:22 INFO:Complete items 04000
# 11:16:22 INFO:Complete items 04000
# 11:16:24 INFO:Complete items 05000
# 11:16:24 INFO:Complete items 05000
# 11:16:25 INFO:Complete items 06000
# 11:16:25 INFO:Complete items 06000
# 11:16:27 INFO:Complete items 07000
# 11:16:27 INFO:Complete items 07000
# threshold 0
# 	class_prec 0.583333333333, class_recall 1.0, class_F1 0.736842105263
# 	not_class_prec 0.0, not_class_recall 0.0, not_class_F1 0.0
# 		MacroF1Mesure 0.368421052632
# threshold 0.001
# 	class_prec 0.585160922814, class_recall 1.0, class_F1 0.738298445782
# 	not_class_prec 1.0, not_class_recall 0.00749574105622, not_class_F1 0.0148799458911
# 		MacroF1Mesure 0.376589195837
# threshold 0.002
# 	class_prec 0.597585805701, class_recall 1.0, class_F1 0.748111060537
# 	not_class_prec 1.0, not_class_recall 0.0572402044293, not_class_F1 0.108282307444
# 		MacroF1Mesure 0.428196683991
# threshold 0.003
# 	class_prec 0.624468085106, class_recall 1.0, class_F1 0.768827766863
# 	not_class_prec 1.0, not_class_recall 0.158091993186, not_class_F1 0.273021476905
# 		MacroF1Mesure 0.520924621884
# threshold 0.004
# 	class_prec 0.655238398979, class_recall 1.0, class_F1 0.791714836224
# 	not_class_prec 1.0, not_class_recall 0.263373083475, not_class_F1 0.41693635383
# 		MacroF1Mesure 0.604325595027
# threshold 0.005
# 	class_prec 0.685757221573, class_recall 0.999513263568, class_F1 0.813428401664
# 	not_class_prec 0.998104265403, not_class_recall 0.358773424191, not_class_F1 0.527819548872
# 		MacroF1Mesure 0.670623975268
# threshold 0.006
# 	class_prec 0.715380595715, class_recall 0.999513263568, class_F1 0.833908629442
# 	not_class_prec 0.998465080583, not_class_recall 0.443270868825, not_class_F1 0.613968853233
# 		MacroF1Mesure 0.723938741337
# threshold 0.007
# 	class_prec 0.736417428725, class_recall 0.999513263568, class_F1 0.848028081767
# 	not_class_prec 0.998636673483, not_class_recall 0.499148211244, not_class_F1 0.665606542481
# 		MacroF1Mesure 0.756817312124
# threshold 0.008
# 	class_prec 0.749589341121, class_recall 0.999513263568, class_F1 0.856695869837
# 	not_class_prec 0.998722044728, not_class_recall 0.532538330494, not_class_F1 0.694666666667
# 		MacroF1Mesure 0.775681268252
# threshold 0.009
# 	class_prec 0.760414738011, class_recall 0.999513263568, class_F1 0.863722397476
# 	not_class_prec 0.998782714547, not_class_recall 0.559114139693, not_class_F1 0.716906946265
# 		MacroF1Mesure 0.790314671871
# threshold 0.01
# 	class_prec 0.769101123596, class_recall 0.999513263568, class_F1 0.869298338449
# 	not_class_prec 0.99882629108, not_class_recall 0.579897785349, not_class_F1 0.733778831645
# 		MacroF1Mesure 0.801538585047
# threshold 0.011
# 	class_prec 0.775198187995, class_recall 0.999513263568, class_F1 0.873179547146
# 	not_class_prec 0.998854524628, not_class_recall 0.594207836457, not_class_F1 0.745139927366
# 		MacroF1Mesure 0.809159737256
# threshold 0.012
# 	class_prec 0.778979320812, class_recall 0.999269895352, class_F1 0.875479744136
# 	not_class_prec 0.998307952623, not_class_recall 0.603066439523, not_class_F1 0.751911639762
# 		MacroF1Mesure 0.813695691949
# threshold 0.013
# 	class_prec 0.782095238095, class_recall 0.999269895352, class_F1 0.877444171386
# 	not_class_prec 0.998327759197, not_class_recall 0.610221465077, not_class_F1 0.75745400719
# 		MacroF1Mesure 0.817449089288
# threshold 0.014
# 	class_prec 0.788251103859, class_recall 0.999269895352, class_F1 0.881305001073
# 	not_class_prec 0.998365122616, not_class_recall 0.624190800681, not_class_F1 0.768134171908
# 		MacroF1Mesure 0.82471958649
# threshold 0.015
# 	class_prec 0.792052469136, class_recall 0.999269895352, class_F1 0.883675885075
# 	not_class_prec 0.998387096774, not_class_recall 0.632708688245, not_class_F1 0.774556830031
# 		MacroF1Mesure 0.829116357553
# threshold 0.016
# 	class_prec 0.798949007396, class_recall 0.999026527136, class_F1 0.887855520709
# 	not_class_prec 0.997901364113, not_class_recall 0.64804088586, not_class_F1 0.785788060318
# 		MacroF1Mesure 0.836821790514
# threshold 0.017
# 	class_prec 0.804825421734, class_recall 0.998539790703, class_F1 0.891278375149
# 	not_class_prec 0.996916752312, not_class_recall 0.660988074957, not_class_F1 0.79491907396
# 		MacroF1Mesure 0.843098724555
# threshold 0.018
# 	class_prec 0.810869565217, class_recall 0.998539790703, class_F1 0.894972188897
# 	not_class_prec 0.996975806452, not_class_recall 0.673935264055, not_class_F1 0.804228501728
# 		MacroF1Mesure 0.849600345313
# threshold 0.019
# 	class_prec 0.819125573967, class_recall 0.998539790703, class_F1 0.899978065365
# 	not_class_prec 0.997051597052, not_class_recall 0.691311754685, not_class_F1 0.816498993964
# 		MacroF1Mesure 0.858238529664
# threshold 0.02
# 	class_prec 0.825684380032, class_recall 0.998296422487, class_F1 0.903822848959
# 	not_class_prec 0.996628131021, not_class_recall 0.704940374787, not_class_F1 0.825783276791
# 		MacroF1Mesure 0.864803062875
# threshold 0.021
# 	class_prec 0.831542671802, class_recall 0.998296422487, class_F1 0.907321389073
# 	not_class_prec 0.996684036002, not_class_recall 0.716865417376, not_class_F1 0.833927863654
# 		MacroF1Mesure 0.870624626364
# threshold 0.022
# 	class_prec 0.836426677544, class_recall 0.998053054271, class_F1 0.910119840213
# 	not_class_prec 0.996263428305, not_class_recall 0.726746166951, not_class_F1 0.840425531915
# 		MacroF1Mesure 0.875272686064
# threshold 0.023
# 	class_prec 0.842927631579, class_recall 0.997809686055, class_F1 0.913852669118
# 	not_class_prec 0.995871559633, not_class_recall 0.739693356048, not_class_F1 0.848875855327
# 		MacroF1Mesure 0.881364262223
# threshold 0.024
# 	class_prec 0.846026831785, class_recall 0.997566317839, class_F1 0.915568461023
# 	not_class_prec 0.995452478399, not_class_recall 0.745826235094, not_class_F1 0.852746396572
# 		MacroF1Mesure 0.884157428797
# threshold 0.025
# 	class_prec 0.848622903293, class_recall 0.997322949623, class_F1 0.916983665249
# 	not_class_prec 0.995033860045, not_class_recall 0.750936967632, not_class_F1 0.855922330097
# 		MacroF1Mesure 0.886452997673
# threshold 0.026
# 	class_prec 0.854105877449, class_recall 0.997322949623, class_F1 0.920175143146
# 	not_class_prec 0.995102404274, not_class_recall 0.761499148211, not_class_F1 0.862767805443
# 		MacroF1Mesure 0.891471474294
# threshold 0.027
# 	class_prec 0.858939425697, class_recall 0.997322949623, class_F1 0.922972972973
# 	not_class_prec 0.99516058073, not_class_recall 0.77069846678, not_class_F1 0.86866359447
# 		MacroF1Mesure 0.895818283722
# threshold 0.028
# 	class_prec 0.861981906165, class_recall 0.997079581407, class_F1 0.924621981494
# 	not_class_prec 0.994762112615, not_class_recall 0.776490630324, not_class_F1 0.87217757367
# 		MacroF1Mesure 0.898399777582
# threshold 0.029
# 	class_prec 0.863981442429, class_recall 0.997079581407, class_F1 0.925771099311
# 	not_class_prec 0.994787141616, not_class_recall 0.780238500852, not_class_F1 0.874546496086
# 		MacroF1Mesure 0.900158797698
# threshold 0.03
# 	class_prec 0.867924528302, class_recall 0.996349476758, class_F1 0.927713573533
# 	not_class_prec 0.993553932101, not_class_recall 0.787734241908, not_class_F1 0.878753325732
# 		MacroF1Mesure 0.903233449632
# threshold 0.031
# 	class_prec 0.86968537415, class_recall 0.99561937211, class_F1 0.928401225462
# 	not_class_prec 0.992307692308, not_class_recall 0.791141396934, not_class_F1 0.880379146919
# 		MacroF1Mesure 0.904390186191
# threshold 0.032
# 	class_prec 0.872998932764, class_recall 0.995376003894, class_F1 0.930179667955
# 	not_class_prec 0.99194573972, not_class_recall 0.79727427598, not_class_F1 0.884019644881
# 		MacroF1Mesure 0.907099656418
# threshold 0.033
# 	class_prec 0.876741693462, class_recall 0.995376003894, class_F1 0.932299977205
# 	not_class_prec 0.99201345103, not_class_recall 0.804088586031, not_class_F1 0.888219796763
# 		MacroF1Mesure 0.910259886984
# threshold 0.034
# 	class_prec 0.878410311493, class_recall 0.995132635678, class_F1 0.933135554541
# 	not_class_prec 0.991628296358, not_class_recall 0.807155025554, not_class_F1 0.889932381668
# 		MacroF1Mesure 0.911533968105
# threshold 0.035
# 	class_prec 0.880654890134, class_recall 0.994889267462, class_F1 0.934293223632
# 	not_class_prec 0.991257285595, not_class_recall 0.811243611584, not_class_F1 0.892261570171
# 		MacroF1Mesure 0.913277396901
# threshold 0.036
# 	class_prec 0.884848484848, class_recall 0.994889267462, class_F1 0.936647955092
# 	not_class_prec 0.991336633663, not_class_recall 0.818739352641, not_class_F1 0.896809106177
# 		MacroF1Mesure 0.916728530634
# threshold 0.037
# 	class_prec 0.888309430682, class_recall 0.994889267462, class_F1 0.938583400298
# 	not_class_prec 0.9914004914, not_class_recall 0.824872231687, not_class_F1 0.900502138739
# 		MacroF1Mesure 0.919542769519
# threshold 0.038
# 	class_prec 0.891773947196, class_recall 0.994645899246, class_F1 0.940404970087
# 	not_class_prec 0.991060544494, not_class_recall 0.831005110733, not_class_F1 0.904002965159
# 		MacroF1Mesure 0.922203967623
# threshold 0.039
# 	class_prec 0.894115073288, class_recall 0.994645899246, class_F1 0.941705069124
# 	not_class_prec 0.991103922362, not_class_recall 0.835093696763, not_class_F1 0.906434911243
# 		MacroF1Mesure 0.924069990184
# threshold 0.04
# 	class_prec 0.895463510848, class_recall 0.994402531029, class_F1 0.942343173432
# 	not_class_prec 0.990729544538, not_class_recall 0.837478705281, not_class_F1 0.907680945347
# 		MacroF1Mesure 0.925012059389
# threshold 0.041
# 	class_prec 0.896642527979, class_recall 0.994402531029, class_F1 0.942995615047
# 	not_class_prec 0.990751909932, not_class_recall 0.839522998296, not_class_F1 0.908889708595
# 		MacroF1Mesure 0.925942661821
# threshold 0.042
# 	class_prec 0.897233201581, class_recall 0.994402531029, class_F1 0.943322174766
# 	not_class_prec 0.990763052209, not_class_recall 0.840545144804, not_class_F1 0.909493087558
# 		MacroF1Mesure 0.926407631162
# threshold 0.043
# 	class_prec 0.89900990099, class_recall 0.994402531029, class_F1 0.944303212387
# 	not_class_prec 0.990796318527, not_class_recall 0.843611584327, not_class_F1 0.911299227089
# 		MacroF1Mesure 0.927801219738
# threshold 0.044
# 	class_prec 0.900970445523, class_recall 0.994159162813, class_F1 0.945273631841
# 	not_class_prec 0.990438247012, not_class_recall 0.847018739353, not_class_F1 0.913131313131
# 		MacroF1Mesure 0.929202472486
# threshold 0.045
# 	class_prec 0.903561159036, class_recall 0.994159162813, class_F1 0.946697566628
# 	not_class_prec 0.990487514863, not_class_recall 0.851448040886, not_class_F1 0.915720043972
# 		MacroF1Mesure 0.9312088053
# threshold 0.046
# 	class_prec 0.905965846086, class_recall 0.994159162813, class_F1 0.948015780924
# 	not_class_prec 0.990532544379, not_class_recall 0.855536626917, not_class_F1 0.918098720293
# 		MacroF1Mesure 0.933057250608
# threshold 0.047
# 	class_prec 0.907312736164, class_recall 0.993429058165, class_F1 0.948420074349
# 	not_class_prec 0.989390962672, not_class_recall 0.857921635434, not_class_F1 0.91897810219
# 		MacroF1Mesure 0.93369908827
# threshold 0.048
# 	class_prec 0.908928969049, class_recall 0.993429058165, class_F1 0.949302325581
# 	not_class_prec 0.989424206816, not_class_recall 0.860647359455, not_class_F1 0.92055393586
# 		MacroF1Mesure 0.934928130721
# threshold 0.049
# 	class_prec 0.910550970332, class_recall 0.993429058165, class_F1 0.950186219739
# 	not_class_prec 0.989457243264, not_class_recall 0.863373083475, not_class_F1 0.922125181951
# 		MacroF1Mesure 0.936155700845
# threshold 0.05
# 	class_prec 0.911160714286, class_recall 0.993429058165, class_F1 0.950518104552
# 	not_class_prec 0.989469578783, not_class_recall 0.864395229983, not_class_F1 0.922713220586
# 		MacroF1Mesure 0.936615662569
# threshold 0.051
# 	class_prec 0.912994855737, class_recall 0.993429058165, class_F1 0.951515151515
# 	not_class_prec 0.989506412748, not_class_recall 0.867461669506, not_class_F1 0.924473493101
# 		MacroF1Mesure 0.937994322308
# threshold 0.052
# 	class_prec 0.914017017465, class_recall 0.993429058165, class_F1 0.952069970845
# 	not_class_prec 0.989526764934, not_class_recall 0.869165247019, not_class_F1 0.925448938872
# 		MacroF1Mesure 0.938759454859
# threshold 0.053
# 	class_prec 0.914631413847, class_recall 0.993429058165, class_F1 0.952403173122
# 	not_class_prec 0.989538938396, not_class_recall 0.870187393526, not_class_F1 0.926033357505
# 		MacroF1Mesure 0.939218265314
# threshold 0.054
# 	class_prec 0.916479568927, class_recall 0.993429058165, class_F1 0.953404180778
# 	not_class_prec 0.989575289575, not_class_recall 0.873253833049, not_class_F1 0.92778280543
# 		MacroF1Mesure 0.940593493104
# threshold 0.055
# 	class_prec 0.917303370787, class_recall 0.993429058165, class_F1 0.953849748802
# 	not_class_prec 0.989591364688, not_class_recall 0.87461669506, not_class_F1 0.928558509676
# 		MacroF1Mesure 0.941204129239
# threshold 0.056
# 	class_prec 0.917678812416, class_recall 0.992942321733, class_F1 0.95382817066
# 	not_class_prec 0.98883756736, not_class_recall 0.875298126065, not_class_F1 0.928610157238
# 		MacroF1Mesure 0.941219163949
# threshold 0.057
# 	class_prec 0.919540229885, class_recall 0.992942321733, class_F1 0.954832670255
# 	not_class_prec 0.9888761028, not_class_recall 0.878364565588, not_class_F1 0.930350054132
# 		MacroF1Mesure 0.942591362194
# threshold 0.058
# 	class_prec 0.921391461486, class_recall 0.992698953517, class_F1 0.955716963449
# 	not_class_prec 0.988536492167, not_class_recall 0.881431005111, not_class_F1 0.931916426513
# 		MacroF1Mesure 0.943816694981
# threshold 0.059
# 	class_prec 0.922641936214, class_recall 0.992698953517, class_F1 0.956389214537
# 	not_class_prec 0.988562714449, not_class_recall 0.883475298126, not_class_F1 0.933069449442
# 		MacroF1Mesure 0.94472933199
# threshold 0.06
# 	class_prec 0.923059515728, class_recall 0.992698953517, class_F1 0.956613508443
# 	not_class_prec 0.988571428571, not_class_recall 0.884156729131, not_class_F1 0.93345323741
# 		MacroF1Mesure 0.945033372926
# threshold 0.061
# 	class_prec 0.923059515728, class_recall 0.992698953517, class_F1 0.956613508443
# 	not_class_prec 0.988571428571, not_class_recall 0.884156729131, not_class_F1 0.93345323741
# 		MacroF1Mesure 0.945033372926
# threshold 0.062
# 	class_prec 0.923686594203, class_recall 0.992698953517, class_F1 0.956950146628
# 	not_class_prec 0.988584474886, not_class_recall 0.885178875639, not_class_F1 0.934028401941
# 		MacroF1Mesure 0.945489274284
# threshold 0.063
# 	class_prec 0.924087922048, class_recall 0.992455585301, class_F1 0.957052335133
# 	not_class_prec 0.98821740783, not_class_recall 0.885860306644, not_class_F1 0.934243621991
# 		MacroF1Mesure 0.945647978562
# threshold 0.064
# 	class_prec 0.924506914532, class_recall 0.992455585301, class_F1 0.957276995305
# 	not_class_prec 0.988226357767, not_class_recall 0.886541737649, not_class_F1 0.934626436782
# 		MacroF1Mesure 0.945951716043
# threshold 0.065
# 	class_prec 0.925942753294, class_recall 0.991968848868, class_F1 0.95781929268
# 	not_class_prec 0.987509462528, not_class_recall 0.888926746167, not_class_F1 0.93562847409
# 		MacroF1Mesure 0.946723883385
# threshold 0.066
# 	class_prec 0.926574221414, class_recall 0.991968848868, class_F1 0.958157028679
# 	not_class_prec 0.98752362949, not_class_recall 0.889948892675, not_class_F1 0.936200716846
# 		MacroF1Mesure 0.947178872762
# threshold 0.067
# 	class_prec 0.926784902228, class_recall 0.991968848868, class_F1 0.95826966028
# 	not_class_prec 0.987528344671, not_class_recall 0.890289608177, not_class_F1 0.936391327719
# 		MacroF1Mesure 0.947330493999
# threshold 0.068
# 	class_prec 0.927384475302, class_recall 0.991482112436, class_F1 0.958362738179
# 	not_class_prec 0.98679743493, not_class_recall 0.891311754685, not_class_F1 0.936627282492
# 		MacroF1Mesure 0.947495010336
# threshold 0.069
# 	class_prec 0.927806877704, class_recall 0.991482112436, class_F1 0.958588235294
# 	not_class_prec 0.986807387863, not_class_recall 0.89199318569, not_class_F1 0.937007874016
# 		MacroF1Mesure 0.947798054655
# threshold 0.07
# 	class_prec 0.928001822739, class_recall 0.99123874422, class_F1 0.958578489056
# 	not_class_prec 0.986440677966, not_class_recall 0.892333901193, not_class_F1 0.937030411449
# 		MacroF1Mesure 0.947804450253
# threshold 0.071
# 	class_prec 0.928424891726, class_recall 0.99123874422, class_F1 0.958804143126
# 	not_class_prec 0.986450884456, not_class_recall 0.893015332198, not_class_F1 0.937410586552
# 		MacroF1Mesure 0.948107364839
# threshold 0.072
# 	class_prec 0.928620296465, class_recall 0.990995376004, class_F1 0.958794443136
# 	not_class_prec 0.986084994359, not_class_recall 0.8933560477, not_class_F1 0.93743296389
# 		MacroF1Mesure 0.948113703513
# threshold 0.073
# 	class_prec 0.929892669559, class_recall 0.990995376004, class_F1 0.959472196041
# 	not_class_prec 0.986116322702, not_class_recall 0.895400340716, not_class_F1 0.938571428571
# 		MacroF1Mesure 0.949021812306
# threshold 0.074
# 	class_prec 0.930742857143, class_recall 0.990995376004, class_F1 0.959924563885
# 	not_class_prec 0.986137130011, not_class_recall 0.896763202726, not_class_F1 0.939329050678
# 		MacroF1Mesure 0.949626807282
# threshold 0.075
# 	class_prec 0.931563286793, class_recall 0.990508639572, class_F1 0.960132106629
# 	not_class_prec 0.985420560748, not_class_recall 0.898126064736, not_class_F1 0.939750445633
# 		MacroF1Mesure 0.949941276131
# threshold 0.076
# 	class_prec 0.932203389831, class_recall 0.990508639572, class_F1 0.960471976401
# 	not_class_prec 0.985436893204, not_class_recall 0.899148211244, not_class_F1 0.940317120969
# 		MacroF1Mesure 0.950394548685
# threshold 0.077
# 	class_prec 0.933700389998, class_recall 0.990508639572, class_F1 0.961265942371
# 	not_class_prec 0.985474860335, not_class_recall 0.901533219761, not_class_F1 0.941637010676
# 		MacroF1Mesure 0.951451476524
# threshold 0.078
# 	class_prec 0.934557979334, class_recall 0.990508639572, class_F1 0.961720226843
# 	not_class_prec 0.985496467088, not_class_recall 0.902896081772, not_class_F1 0.942389758179
# 		MacroF1Mesure 0.952054992511
# threshold 0.079
# 	class_prec 0.934772622876, class_recall 0.990508639572, class_F1 0.96183386506
# 	not_class_prec 0.985501858736, not_class_recall 0.903236797274, not_class_F1 0.942577777778
# 		MacroF1Mesure 0.952205821419
# threshold 0.08
# 	class_prec 0.934987365036, class_recall 0.990508639572, class_F1 0.961947530135
# 	not_class_prec 0.985507246377, not_class_recall 0.903577512777, not_class_F1 0.942765730537
# 		MacroF1Mesure 0.952356630336
# threshold 0.081
# 	class_prec 0.934987365036, class_recall 0.990508639572, class_F1 0.961947530135
# 	not_class_prec 0.985507246377, not_class_recall 0.903577512777, not_class_F1 0.942765730537
# 		MacroF1Mesure 0.952356630336
# threshold 0.082
# 	class_prec 0.935202205882, class_recall 0.990508639572, class_F1 0.962061222078
# 	not_class_prec 0.985512630015, not_class_recall 0.903918228279, not_class_F1 0.942953616492
# 		MacroF1Mesure 0.952507419285
# threshold 0.083
# 	class_prec 0.935847321223, class_recall 0.990508639572, class_F1 0.96240245921
# 	not_class_prec 0.985528756957, not_class_recall 0.904940374787, not_class_F1 0.94351687389
# 		MacroF1Mesure 0.95295966655
# threshold 0.084
# 	class_prec 0.936708860759, class_recall 0.990508639572, class_F1 0.962857818784
# 	not_class_prec 0.985550203779, not_class_recall 0.906303236797, not_class_F1 0.944266950657
# 		MacroF1Mesure 0.95356238472
# threshold 0.085
# 	class_prec 0.936708860759, class_recall 0.990508639572, class_F1 0.962857818784
# 	not_class_prec 0.985550203779, not_class_recall 0.906303236797, not_class_F1 0.944266950657
# 		MacroF1Mesure 0.95356238472
# threshold 0.086
# 	class_prec 0.936694290976, class_recall 0.990265271356, class_F1 0.962735123625
# 	not_class_prec 0.985185185185, not_class_recall 0.906303236797, not_class_F1 0.944099378882
# 		MacroF1Mesure 0.953417251253
# threshold 0.087
# 	class_prec 0.936694290976, class_recall 0.990265271356, class_F1 0.962735123625
# 	not_class_prec 0.985185185185, not_class_recall 0.906303236797, not_class_F1 0.944099378882
# 		MacroF1Mesure 0.953417251253
# threshold 0.088
# 	class_prec 0.936694290976, class_recall 0.990265271356, class_F1 0.962735123625
# 	not_class_prec 0.985185185185, not_class_recall 0.906303236797, not_class_F1 0.944099378882
# 		MacroF1Mesure 0.953417251253
# threshold 0.089
# 	class_prec 0.936909970067, class_recall 0.990265271356, class_F1 0.962849029815
# 	not_class_prec 0.985190670122, not_class_recall 0.9066439523, not_class_F1 0.944286728176
# 		MacroF1Mesure 0.953567878996
# threshold 0.09
# 	class_prec 0.937125748503, class_recall 0.990265271356, class_F1 0.962962962963
# 	not_class_prec 0.985196150999, not_class_recall 0.906984667802, not_class_F1 0.944474010999
# 		MacroF1Mesure 0.953718486981
# threshold 0.091
# 	class_prec 0.937312744872, class_recall 0.989778534923, class_F1 0.962831439394
# 	not_class_prec 0.984473197782, not_class_recall 0.907325383305, not_class_F1 0.944326241135
# 		MacroF1Mesure 0.953578840264
# threshold 0.092
# 	class_prec 0.937961254613, class_recall 0.989778534923, class_F1 0.963173475429
# 	not_class_prec 0.984490398818, not_class_recall 0.908347529813, not_class_F1 0.944887471203
# 		MacroF1Mesure 0.954030473316
# threshold 0.093
# 	class_prec 0.938177623991, class_recall 0.989778534923, class_F1 0.96328754145
# 	not_class_prec 0.984496124031, not_class_recall 0.908688245315, not_class_F1 0.945074415308
# 		MacroF1Mesure 0.954180978379
# threshold 0.094
# 	class_prec 0.938177623991, class_recall 0.989778534923, class_F1 0.96328754145
# 	not_class_prec 0.984496124031, not_class_recall 0.908688245315, not_class_F1 0.945074415308
# 		MacroF1Mesure 0.954180978379
# threshold 0.095
# 	class_prec 0.938596491228, class_recall 0.989535166707, class_F1 0.963392962919
# 	not_class_prec 0.984144542773, not_class_recall 0.90936967632, not_class_F1 0.945280680007
# 		MacroF1Mesure 0.954336821463
# threshold 0.096
# 	class_prec 0.938813207112, class_recall 0.989535166707, class_F1 0.963507109005
# 	not_class_prec 0.984150387025, not_class_recall 0.909710391823, not_class_F1 0.945467422096
# 		MacroF1Mesure 0.954487265551
# threshold 0.097
# 	class_prec 0.939030023095, class_recall 0.989535166707, class_F1 0.963621282142
# 	not_class_prec 0.984156226971, not_class_recall 0.910051107325, not_class_F1 0.94565409807
# 		MacroF1Mesure 0.954637690106
# threshold 0.098
# 	class_prec 0.939435968562, class_recall 0.989048430275, class_F1 0.963604030824
# 	not_class_prec 0.983443708609, not_class_recall 0.91073253833, not_class_F1 0.945692552627
# 		MacroF1Mesure 0.954648291725
# threshold 0.099
# 	class_prec 0.939653179191, class_recall 0.989048430275, class_F1 0.96371828314
# 	not_class_prec 0.98344979772, not_class_recall 0.911073253833, not_class_F1 0.9458790237
# 		MacroF1Mesure 0.95479865342
# threshold 0.1
# 	class_prec 0.939870490287, class_recall 0.989048430275, class_F1 0.963832562552
# 	not_class_prec 0.983455882353, not_class_recall 0.911413969336, not_class_F1 0.946065428824
# 		MacroF1Mesure 0.954948995688
# threshold 0.101
# 	class_prec 0.94030541416, class_recall 0.989048430275, class_F1 0.964061202704
# 	not_class_prec 0.983468038207, not_class_recall 0.912095400341, not_class_F1 0.946438041365
# 		MacroF1Mesure 0.955249622034
# threshold 0.102
# 	class_prec 0.940740740741, class_recall 0.989048430275, class_F1 0.964289951358
# 	not_class_prec 0.983480176211, not_class_recall 0.912776831346, not_class_F1 0.946810390528
# 		MacroF1Mesure 0.955550170943
# threshold 0.103
# 	class_prec 0.940958555221, class_recall 0.989048430275, class_F1 0.964404366398
# 	not_class_prec 0.983486238532, not_class_recall 0.913117546848, not_class_F1 0.946996466431
# 		MacroF1Mesure 0.955700416414
# threshold 0.104
# 	class_prec 0.941162844568, class_recall 0.988805062059, class_F1 0.964395917399
# 	not_class_prec 0.983131646498, not_class_recall 0.913458262351, not_class_F1 0.947015188979
# 		MacroF1Mesure 0.955705553189
# threshold 0.105
# 	class_prec 0.941162844568, class_recall 0.988805062059, class_F1 0.964395917399
# 	not_class_prec 0.983131646498, not_class_recall 0.913458262351, not_class_F1 0.947015188979
# 		MacroF1Mesure 0.955705553189
# threshold 0.106
# 	class_prec 0.942035706005, class_recall 0.988805062059, class_F1 0.96485395393
# 	not_class_prec 0.983156352984, not_class_recall 0.914821124361, not_class_F1 0.947758559831
# 		MacroF1Mesure 0.95630625688
# threshold 0.107
# 	class_prec 0.942035706005, class_recall 0.988805062059, class_F1 0.96485395393
# 	not_class_prec 0.983156352984, not_class_recall 0.914821124361, not_class_F1 0.947758559831
# 		MacroF1Mesure 0.95630625688
# threshold 0.108
# 	class_prec 0.942254174397, class_recall 0.988805062059, class_F1 0.964968531053
# 	not_class_prec 0.983162518302, not_class_recall 0.915161839864, not_class_F1 0.947944238574
# 		MacroF1Mesure 0.956456384814
# threshold 0.109
# 	class_prec 0.942240779402, class_recall 0.988561693843, class_F1 0.964845605701
# 	not_class_prec 0.982802780827, not_class_recall 0.915161839864, not_class_F1 0.947776993649
# 		MacroF1Mesure 0.956311299675
# threshold 0.11
# 	class_prec 0.942240779402, class_recall 0.988561693843, class_F1 0.964845605701
# 	not_class_prec 0.982802780827, not_class_recall 0.915161839864, not_class_F1 0.947776993649
# 		MacroF1Mesure 0.956311299675
# threshold 0.111
# 	class_prec 0.942459396752, class_recall 0.988561693843, class_F1 0.964960209051
# 	not_class_prec 0.982809070958, not_class_recall 0.915502555366, not_class_F1 0.947962603634
# 		MacroF1Mesure 0.956461406342
# threshold 0.112
# 	class_prec 0.942459396752, class_recall 0.988561693843, class_F1 0.964960209051
# 	not_class_prec 0.982809070958, not_class_recall 0.915502555366, not_class_F1 0.947962603634
# 		MacroF1Mesure 0.956461406342
# threshold 0.113
# 	class_prec 0.942896935933, class_recall 0.988561693843, class_F1 0.965189497446
# 	not_class_prec 0.982821637427, not_class_recall 0.916183986371, not_class_F1 0.948333627226
# 		MacroF1Mesure 0.956761562336
# threshold 0.114
# 	class_prec 0.943334881561, class_recall 0.988561693843, class_F1 0.965418894831
# 	not_class_prec 0.982834185537, not_class_recall 0.916865417376, not_class_F1 0.948704389212
# 		MacroF1Mesure 0.957061642021
# threshold 0.115
# 	class_prec 0.943992563328, class_recall 0.988561693843, class_F1 0.965763195435
# 	not_class_prec 0.982852973367, not_class_recall 0.917887563884, not_class_F1 0.949260042283
# 		MacroF1Mesure 0.957511618859
# threshold 0.116
# 	class_prec 0.944211994421, class_recall 0.988561693843, class_F1 0.965878016883
# 	not_class_prec 0.982859226842, not_class_recall 0.918228279387, not_class_F1 0.94944512947
# 		MacroF1Mesure 0.957661573176
# threshold 0.117
# 	class_prec 0.944431527552, class_recall 0.988561693843, class_F1 0.965992865636
# 	not_class_prec 0.982865475756, not_class_recall 0.918568994889, not_class_F1 0.949630151462
# 		MacroF1Mesure 0.957811508549
# threshold 0.118
# 	class_prec 0.944431527552, class_recall 0.988561693843, class_F1 0.965992865636
# 	not_class_prec 0.982865475756, not_class_recall 0.918568994889, not_class_F1 0.949630151462
# 		MacroF1Mesure 0.957811508549
# threshold 0.119
# 	class_prec 0.944651162791, class_recall 0.988561693843, class_F1 0.966107741705
# 	not_class_prec 0.982871720117, not_class_recall 0.918909710392, not_class_F1 0.949815108294
# 		MacroF1Mesure 0.957961425
# threshold 0.12
# 	class_prec 0.944870900209, class_recall 0.988561693843, class_F1 0.9662226451
# 	not_class_prec 0.982877959927, not_class_recall 0.919250425894, not_class_F1 0.95
# 		MacroF1Mesure 0.95811132255
# threshold 0.121
# 	class_prec 0.944870900209, class_recall 0.988561693843, class_F1 0.9662226451
# 	not_class_prec 0.982877959927, not_class_recall 0.919250425894, not_class_F1 0.95
# 		MacroF1Mesure 0.95811132255
# threshold 0.122
# 	class_prec 0.944858073523, class_recall 0.988318325627, class_F1 0.966099678839
# 	not_class_prec 0.982520029133, not_class_recall 0.919250425894, not_class_F1 0.94983277592
# 		MacroF1Mesure 0.957966227379
# threshold 0.123
# 	class_prec 0.944858073523, class_recall 0.988318325627, class_F1 0.966099678839
# 	not_class_prec 0.982520029133, not_class_recall 0.919250425894, not_class_F1 0.94983277592
# 		MacroF1Mesure 0.957966227379
# threshold 0.124
# 	class_prec 0.944858073523, class_recall 0.988318325627, class_F1 0.966099678839
# 	not_class_prec 0.982520029133, not_class_recall 0.919250425894, not_class_F1 0.94983277592
# 		MacroF1Mesure 0.957966227379
# threshold 0.125
# 	class_prec 0.945297951583, class_recall 0.988318325627, class_F1 0.966329565735
# 	not_class_prec 0.982532751092, not_class_recall 0.919931856899, not_class_F1 0.95020235791
# 		MacroF1Mesure 0.958265961822
# threshold 0.126
# 	class_prec 0.945297951583, class_recall 0.988318325627, class_F1 0.966329565735
# 	not_class_prec 0.982532751092, not_class_recall 0.919931856899, not_class_F1 0.95020235791
# 		MacroF1Mesure 0.958265961822
# threshold 0.127
# 	class_prec 0.945518044237, class_recall 0.988318325627, class_F1 0.966444550214
# 	not_class_prec 0.982539105129, not_class_recall 0.920272572402, not_class_F1 0.950387051372
# 		MacroF1Mesure 0.958415800793
# threshold 0.128
# 	class_prec 0.945518044237, class_recall 0.988318325627, class_F1 0.966444550214
# 	not_class_prec 0.982539105129, not_class_recall 0.920272572402, not_class_F1 0.950387051372
# 		MacroF1Mesure 0.958415800793
# threshold 0.129
# 	class_prec 0.945725599814, class_recall 0.988074957411, class_F1 0.966436562723
# 	not_class_prec 0.982188295165, not_class_recall 0.920613287905, not_class_F1 0.950404502286
# 		MacroF1Mesure 0.958420532505
# threshold 0.13
# 	class_prec 0.945725599814, class_recall 0.988074957411, class_F1 0.966436562723
# 	not_class_prec 0.982188295165, not_class_recall 0.920613287905, not_class_F1 0.950404502286
# 		MacroF1Mesure 0.958420532505
# threshold 0.131
# 	class_prec 0.945725599814, class_recall 0.988074957411, class_F1 0.966436562723
# 	not_class_prec 0.982188295165, not_class_recall 0.920613287905, not_class_F1 0.950404502286
# 		MacroF1Mesure 0.958420532505
# threshold 0.132
# 	class_prec 0.94616639478, class_recall 0.988074957411, class_F1 0.966666666667
# 	not_class_prec 0.982201235016, not_class_recall 0.92129471891, not_class_F1 0.950773558368
# 		MacroF1Mesure 0.958720112518
# threshold 0.133
# 	class_prec 0.94616639478, class_recall 0.988074957411, class_F1 0.966666666667
# 	not_class_prec 0.982201235016, not_class_recall 0.92129471891, not_class_F1 0.950773558368
# 		MacroF1Mesure 0.958720112518
# threshold 0.134
# 	class_prec 0.946386946387, class_recall 0.988074957411, class_F1 0.966781759733
# 	not_class_prec 0.982207697894, not_class_recall 0.921635434412, not_class_F1 0.950957989102
# 		MacroF1Mesure 0.958869874418
# threshold 0.135
# 	class_prec 0.947049218568, class_recall 0.988074957411, class_F1 0.96712720343
# 	not_class_prec 0.982227058397, not_class_recall 0.92265758092, not_class_F1 0.951510892481
# 		MacroF1Mesure 0.959319047955
# threshold 0.136
# 	class_prec 0.947491248541, class_recall 0.988074957411, class_F1 0.967357636407
# 	not_class_prec 0.982239942008, not_class_recall 0.923339011925, not_class_F1 0.951879171057
# 		MacroF1Mesure 0.959618403732
# threshold 0.137
# 	class_prec 0.947491248541, class_recall 0.988074957411, class_F1 0.967357636407
# 	not_class_prec 0.982239942008, not_class_recall 0.923339011925, not_class_F1 0.951879171057
# 		MacroF1Mesure 0.959618403732
# threshold 0.138
# 	class_prec 0.947712418301, class_recall 0.988074957411, class_F1 0.967472894078
# 	not_class_prec 0.982246376812, not_class_recall 0.923679727428, not_class_F1 0.952063213345
# 		MacroF1Mesure 0.959768053712
# threshold 0.139
# 	class_prec 0.947933691338, class_recall 0.988074957411, class_F1 0.967588179218
# 	not_class_prec 0.982252806954, not_class_recall 0.92402044293, not_class_F1 0.952247191011
# 		MacroF1Mesure 0.959917685115
# threshold 0.14
# 	class_prec 0.948142957253, class_recall 0.987831589194, class_F1 0.96758045292
# 	not_class_prec 0.981903727832, not_class_recall 0.924361158433, not_class_F1 0.952263952264
# 		MacroF1Mesure 0.959922202592
# threshold 0.141
# 	class_prec 0.948586118252, class_recall 0.987831589194, class_F1 0.967811158798
# 	not_class_prec 0.98191681736, not_class_recall 0.925042589438, not_class_F1 0.952631578947
# 		MacroF1Mesure 0.960221368873
# threshold 0.142
# 	class_prec 0.948586118252, class_recall 0.987831589194, class_F1 0.967811158798
# 	not_class_prec 0.98191681736, not_class_recall 0.925042589438, not_class_F1 0.952631578947
# 		MacroF1Mesure 0.960221368873
# threshold 0.143
# 	class_prec 0.948574100047, class_recall 0.987588220978, class_F1 0.967688088709
# 	not_class_prec 0.981561822126, not_class_recall 0.925042589438, not_class_F1 0.952464479916
# 		MacroF1Mesure 0.960076284312
# threshold 0.144
# 	class_prec 0.94901777362, class_recall 0.987588220978, class_F1 0.967918902803
# 	not_class_prec 0.981575144509, not_class_recall 0.925724020443, not_class_F1 0.95283184289
# 		MacroF1Mesure 0.960375372846
# threshold 0.145
# 	class_prec 0.949227889565, class_recall 0.987344852762, class_F1 0.967911248956
# 	not_class_prec 0.981227436823, not_class_recall 0.926064735945, not_class_F1 0.952848378615
# 		MacroF1Mesure 0.960379813786
# threshold 0.146
# 	class_prec 0.949450035104, class_recall 0.987344852762, class_F1 0.968026723932
# 	not_class_prec 0.981234211476, not_class_recall 0.926405451448, not_class_F1 0.95303189625
# 		MacroF1Mesure 0.960529310091
# threshold 0.147
# 	class_prec 0.949438202247, class_recall 0.987101484546, class_F1 0.967903591457
# 	not_class_prec 0.98088023088, not_class_recall 0.926405451448, not_class_F1 0.952864902751
# 		MacroF1Mesure 0.960384247104
# threshold 0.148
# 	class_prec 0.949882903981, class_recall 0.987101484546, class_F1 0.96813462227
# 	not_class_prec 0.980894015862, not_class_recall 0.927086882453, not_class_F1 0.953231739359
# 		MacroF1Mesure 0.960683180814
# threshold 0.149
# 	class_prec 0.950105411103, class_recall 0.987101484546, class_F1 0.96825017904
# 	not_class_prec 0.980900900901, not_class_recall 0.927427597956, not_class_F1 0.953415061296
# 		MacroF1Mesure 0.960832620168
# threshold 0.15
# 	class_prec 0.950328022493, class_recall 0.987101484546, class_F1 0.9683657634
# 	not_class_prec 0.98090778098, not_class_recall 0.927768313458, not_class_F1 0.953598319033
# 		MacroF1Mesure 0.960982041217
# threshold 0.151
# 	class_prec 0.950773558368, class_recall 0.987101484546, class_F1 0.968597014925
# 	not_class_prec 0.980921526278, not_class_recall 0.928449744463, not_class_F1 0.953964642044
# 		MacroF1Mesure 0.961280828485
# threshold 0.152
# 	class_prec 0.951208069435, class_recall 0.98685811633, class_F1 0.968705207836
# 	not_class_prec 0.980582524272, not_class_recall 0.929131175468, not_class_F1 0.954163750875
# 		MacroF1Mesure 0.961434479355
# threshold 0.153
# 	class_prec 0.951208069435, class_recall 0.98685811633, class_F1 0.968705207836
# 	not_class_prec 0.980582524272, not_class_recall 0.929131175468, not_class_F1 0.954163750875
# 		MacroF1Mesure 0.961434479355
# threshold 0.154
# 	class_prec 0.951431252933, class_recall 0.98685811633, class_F1 0.968820929399
# 	not_class_prec 0.980589503954, not_class_recall 0.929471890971, not_class_F1 0.954346685324
# 		MacroF1Mesure 0.961583807362
# threshold 0.155
# 	class_prec 0.951431252933, class_recall 0.98685811633, class_F1 0.968820929399
# 	not_class_prec 0.980589503954, not_class_recall 0.929471890971, not_class_F1 0.954346685324
# 		MacroF1Mesure 0.961583807362
# threshold 0.156
# 	class_prec 0.951419854494, class_recall 0.986614748114, class_F1 0.968697729988
# 	not_class_prec 0.98023715415, not_class_recall 0.929471890971, not_class_F1 0.954179783141
# 		MacroF1Mesure 0.961438756565
# threshold 0.157
# 	class_prec 0.95186663536, class_recall 0.986614748114, class_F1 0.968929254302
# 	not_class_prec 0.980251346499, not_class_recall 0.930153321976, not_class_F1 0.954545454545
# 		MacroF1Mesure 0.961737354424
# threshold 0.158
# 	class_prec 0.95186663536, class_recall 0.986614748114, class_F1 0.968929254302
# 	not_class_prec 0.980251346499, not_class_recall 0.930153321976, not_class_F1 0.954545454545
# 		MacroF1Mesure 0.961737354424
# threshold 0.159
# 	class_prec 0.951855331141, class_recall 0.986371379898, class_F1 0.968806023664
# 	not_class_prec 0.979899497487, not_class_recall 0.930153321976, not_class_F1 0.954378605139
# 		MacroF1Mesure 0.961592314402
# threshold 0.16
# 	class_prec 0.952750352609, class_recall 0.986371379898, class_F1 0.969269400933
# 	not_class_prec 0.979928315412, not_class_recall 0.931516183986, not_class_F1 0.955109170306
# 		MacroF1Mesure 0.962189285619
# threshold 0.161
# 	class_prec 0.952974371032, class_recall 0.986371379898, class_F1 0.969385314518
# 	not_class_prec 0.979935506987, not_class_recall 0.931856899489, not_class_F1 0.955291652113
# 		MacroF1Mesure 0.962338483316
# threshold 0.162
# 	class_prec 0.952974371032, class_recall 0.986371379898, class_F1 0.969385314518
# 	not_class_prec 0.979935506987, not_class_recall 0.931856899489, not_class_F1 0.955291652113
# 		MacroF1Mesure 0.962338483316
# threshold 0.163
# 	class_prec 0.953422724065, class_recall 0.986371379898, class_F1 0.96961722488
# 	not_class_prec 0.979949874687, not_class_recall 0.932538330494, not_class_F1 0.955656424581
# 		MacroF1Mesure 0.962636824731
# threshold 0.164
# 	class_prec 0.953422724065, class_recall 0.986371379898, class_F1 0.96961722488
# 	not_class_prec 0.979949874687, not_class_recall 0.932538330494, not_class_F1 0.955656424581
# 		MacroF1Mesure 0.962636824731
# threshold 0.165
# 	class_prec 0.953647058824, class_recall 0.986371379898, class_F1 0.969733221677
# 	not_class_prec 0.979957050823, not_class_recall 0.932879045997, not_class_F1 0.955838715308
# 		MacroF1Mesure 0.962785968493
# threshold 0.166
# 	class_prec 0.953871499176, class_recall 0.986371379898, class_F1 0.969849246231
# 	not_class_prec 0.979964221825, not_class_recall 0.933219761499, not_class_F1 0.956020942408
# 		MacroF1Mesure 0.96293509432
# threshold 0.167
# 	class_prec 0.954096045198, class_recall 0.986371379898, class_F1 0.969965298552
# 	not_class_prec 0.979971387697, not_class_recall 0.933560477002, not_class_F1 0.956203105915
# 		MacroF1Mesure 0.963084202234
# threshold 0.168
# 	class_prec 0.954320696963, class_recall 0.986371379898, class_F1 0.97008137865
# 	not_class_prec 0.979978548445, not_class_recall 0.933901192504, not_class_F1 0.956385205862
# 		MacroF1Mesure 0.963233292256
# threshold 0.169
# 	class_prec 0.954770318021, class_recall 0.986371379898, class_F1 0.970313622217
# 	not_class_prec 0.979992854591, not_class_recall 0.934582623509, not_class_F1 0.956749215208
# 		MacroF1Mesure 0.963531418712
# threshold 0.17
# 	class_prec 0.954995287465, class_recall 0.986371379898, class_F1 0.970429785706
# 	not_class_prec 0.98, not_class_recall 0.934923339012, not_class_F1 0.956931124673
# 		MacroF1Mesure 0.963680455189
# threshold 0.171
# 	class_prec 0.955220362951, class_recall 0.986371379898, class_F1 0.970545977011
# 	not_class_prec 0.980007140307, not_class_recall 0.935264054514, not_class_F1 0.957112970711
# 		MacroF1Mesure 0.963829473861
# threshold 0.172
# 	class_prec 0.955220362951, class_recall 0.986371379898, class_F1 0.970545977011
# 	not_class_prec 0.980007140307, not_class_recall 0.935264054514, not_class_F1 0.957112970711
# 		MacroF1Mesure 0.963829473861
# threshold 0.173
# 	class_prec 0.955670832351, class_recall 0.986371379898, class_F1 0.970778443114
# 	not_class_prec 0.980021405637, not_class_recall 0.93594548552, not_class_F1 0.957476472639
# 		MacroF1Mesure 0.964127457876
# threshold 0.174
# 	class_prec 0.955896226415, class_recall 0.986371379898, class_F1 0.97089471793
# 	not_class_prec 0.98002853067, not_class_recall 0.936286201022, not_class_F1 0.957658128594
# 		MacroF1Mesure 0.964276423262
# threshold 0.175
# 	class_prec 0.956121726822, class_recall 0.986371379898, class_F1 0.971011020604
# 	not_class_prec 0.980035650624, not_class_recall 0.936626916525, not_class_F1 0.957839721254
# 		MacroF1Mesure 0.964425370929
# threshold 0.176
# 	class_prec 0.956347333648, class_recall 0.986371379898, class_F1 0.971127351144
# 	not_class_prec 0.980042765502, not_class_recall 0.936967632027, not_class_F1 0.958021250653
# 		MacroF1Mesure 0.964574300899
# threshold 0.177
# 	class_prec 0.956347333648, class_recall 0.986371379898, class_F1 0.971127351144
# 	not_class_prec 0.980042765502, not_class_recall 0.936967632027, not_class_F1 0.958021250653
# 		MacroF1Mesure 0.964574300899
# threshold 0.178
# 	class_prec 0.956347333648, class_recall 0.986371379898, class_F1 0.971127351144
# 	not_class_prec 0.980042765502, not_class_recall 0.936967632027, not_class_F1 0.958021250653
# 		MacroF1Mesure 0.964574300899
# threshold 0.179
# 	class_prec 0.957250826641, class_recall 0.986371379898, class_F1 0.971592952175
# 	not_class_prec 0.980071174377, not_class_recall 0.938330494037, not_class_F1 0.958746736292
# 		MacroF1Mesure 0.965169844234
# threshold 0.18
# 	class_prec 0.957703213611, class_recall 0.986371379898, class_F1 0.971825920153
# 	not_class_prec 0.980085348506, not_class_recall 0.939011925043, not_class_F1 0.9591091004
# 		MacroF1Mesure 0.965467510277
# threshold 0.181
# 	class_prec 0.958156028369, class_recall 0.986371379898, class_F1 0.97205899988
# 	not_class_prec 0.980099502488, not_class_recall 0.939693356048, not_class_F1 0.959471212385
# 		MacroF1Mesure 0.965765106132
# threshold 0.182
# 	class_prec 0.959289940828, class_recall 0.986371379898, class_F1 0.972642188625
# 	not_class_prec 0.980134799574, not_class_recall 0.94139693356, not_class_F1 0.960375391032
# 		MacroF1Mesure 0.966508789829
# threshold 0.183
# 	class_prec 0.959289940828, class_recall 0.986371379898, class_F1 0.972642188625
# 	not_class_prec 0.980134799574, not_class_recall 0.94139693356, not_class_F1 0.960375391032
# 		MacroF1Mesure 0.966508789829
# threshold 0.184
# 	class_prec 0.959289940828, class_recall 0.986371379898, class_F1 0.972642188625
# 	not_class_prec 0.980134799574, not_class_recall 0.94139693356, not_class_F1 0.960375391032
# 		MacroF1Mesure 0.966508789829
# threshold 0.185
# 	class_prec 0.959289940828, class_recall 0.986371379898, class_F1 0.972642188625
# 	not_class_prec 0.980134799574, not_class_recall 0.94139693356, not_class_F1 0.960375391032
# 		MacroF1Mesure 0.966508789829
# threshold 0.186
# 	class_prec 0.959289940828, class_recall 0.986371379898, class_F1 0.972642188625
# 	not_class_prec 0.980134799574, not_class_recall 0.94139693356, not_class_F1 0.960375391032
# 		MacroF1Mesure 0.966508789829
# threshold 0.187
# 	class_prec 0.959289940828, class_recall 0.986371379898, class_F1 0.972642188625
# 	not_class_prec 0.980134799574, not_class_recall 0.94139693356, not_class_F1 0.960375391032
# 		MacroF1Mesure 0.966508789829
# threshold 0.188
# 	class_prec 0.959744257637, class_recall 0.986371379898, class_F1 0.972875660106
# 	not_class_prec 0.980148883375, not_class_recall 0.942078364566, not_class_F1 0.960736622655
# 		MacroF1Mesure 0.96680614138
# threshold 0.189
# 	class_prec 0.959744257637, class_recall 0.986371379898, class_F1 0.972875660106
# 	not_class_prec 0.980148883375, not_class_recall 0.942078364566, not_class_F1 0.960736622655
# 		MacroF1Mesure 0.96680614138
# threshold 0.19
# 	class_prec 0.959744257637, class_recall 0.986371379898, class_F1 0.972875660106
# 	not_class_prec 0.980148883375, not_class_recall 0.942078364566, not_class_F1 0.960736622655
# 		MacroF1Mesure 0.96680614138
# threshold 0.191
# 	class_prec 0.959744257637, class_recall 0.986371379898, class_F1 0.972875660106
# 	not_class_prec 0.980148883375, not_class_recall 0.942078364566, not_class_F1 0.960736622655
# 		MacroF1Mesure 0.96680614138
# threshold 0.192
# 	class_prec 0.96018957346, class_recall 0.986128011682, class_F1 0.972985952695
# 	not_class_prec 0.979815864023, not_class_recall 0.942759795571, not_class_F1 0.960930717138
# 		MacroF1Mesure 0.966958334917
# threshold 0.193
# 	class_prec 0.960417160465, class_recall 0.986128011682, class_F1 0.973102785783
# 	not_class_prec 0.97982300885, not_class_recall 0.943100511073, not_class_F1 0.961111111111
# 		MacroF1Mesure 0.967106948447
# threshold 0.194
# 	class_prec 0.960635522884, class_recall 0.985884643466, class_F1 0.973096324766
# 	not_class_prec 0.979483551468, not_class_recall 0.943441226576, not_class_F1 0.961124609511
# 		MacroF1Mesure 0.967110467138
# threshold 0.195
# 	class_prec 0.960626185958, class_recall 0.985641275249, class_F1 0.972972972973
# 	not_class_prec 0.979137199434, not_class_recall 0.943441226576, not_class_F1 0.960957834461
# 		MacroF1Mesure 0.966965403717
# threshold 0.196
# 	class_prec 0.96106362773, class_recall 0.985154538817, class_F1 0.972959980772
# 	not_class_prec 0.978460451977, not_class_recall 0.944122657581, not_class_F1 0.960984914167
# 		MacroF1Mesure 0.966972447469
# threshold 0.197
# 	class_prec 0.961730449251, class_recall 0.984667802385, class_F1 0.973063973064
# 	not_class_prec 0.977793443779, not_class_recall 0.945144804089, not_class_F1 0.961191961192
# 		MacroF1Mesure 0.967127967128
# threshold 0.198
# 	class_prec 0.961730449251, class_recall 0.984667802385, class_F1 0.973063973064
# 	not_class_prec 0.977793443779, not_class_recall 0.945144804089, not_class_F1 0.961191961192
# 		MacroF1Mesure 0.967127967128
# threshold 0.199
# 	class_prec 0.961730449251, class_recall 0.984667802385, class_F1 0.973063973064
# 	not_class_prec 0.977793443779, not_class_recall 0.945144804089, not_class_F1 0.961191961192
# 		MacroF1Mesure 0.967127967128
# threshold 0.2
# 	class_prec 0.961959106039, class_recall 0.984667802385, class_F1 0.973180998196
# 	not_class_prec 0.977801268499, not_class_recall 0.945485519591, not_class_F1 0.96137190369
# 		MacroF1Mesure 0.967276450943
# threshold 0.201
# 	class_prec 0.962645729241, class_recall 0.984667802385, class_F1 0.973532242541
# 	not_class_prec 0.977824709609, not_class_recall 0.946507666099, not_class_F1 0.961911357341
# 		MacroF1Mesure 0.967721799941
# threshold 0.202
# 	class_prec 0.962645729241, class_recall 0.984667802385, class_F1 0.973532242541
# 	not_class_prec 0.977824709609, not_class_recall 0.946507666099, not_class_F1 0.961911357341
# 		MacroF1Mesure 0.967721799941
# threshold 0.203
# 	class_prec 0.963333333333, class_recall 0.984667802385, class_F1 0.973883740522
# 	not_class_prec 0.977848101266, not_class_recall 0.947529812606, not_class_F1 0.962450250908
# 		MacroF1Mesure 0.968166995715
# threshold 0.204
# 	class_prec 0.963562753036, class_recall 0.984667802385, class_F1 0.974000962927
# 	not_class_prec 0.977855887522, not_class_recall 0.947870528109, not_class_F1 0.962629757785
# 		MacroF1Mesure 0.968315360356
# threshold 0.205
# 	class_prec 0.963554073368, class_recall 0.984424434169, class_F1 0.973877452751
# 	not_class_prec 0.977512297962, not_class_recall 0.947870528109, not_class_F1 0.962463241654
# 		MacroF1Mesure 0.968170347202
# threshold 0.206
# 	class_prec 0.963783654992, class_recall 0.984424434169, class_F1 0.973994702625
# 	not_class_prec 0.977520196698, not_class_recall 0.948211243612, not_class_F1 0.962642684192
# 		MacroF1Mesure 0.968318693408
# threshold 0.207
# 	class_prec 0.963775023832, class_recall 0.984181065953, class_F1 0.973871161951
# 	not_class_prec 0.977176966292, not_class_recall 0.948211243612, not_class_F1 0.962476223413
# 		MacroF1Mesure 0.968173692682
# threshold 0.208
# 	class_prec 0.96400476758, class_recall 0.984181065953, class_F1 0.973988439306
# 	not_class_prec 0.977184977185, not_class_recall 0.948551959114, not_class_F1 0.96265560166
# 		MacroF1Mesure 0.968322020483
# threshold 0.209
# 	class_prec 0.96400476758, class_recall 0.984181065953, class_F1 0.973988439306
# 	not_class_prec 0.977184977185, not_class_recall 0.948551959114, not_class_F1 0.96265560166
# 		MacroF1Mesure 0.968322020483
# threshold 0.21
# 	class_prec 0.96400476758, class_recall 0.984181065953, class_F1 0.973988439306
# 	not_class_prec 0.977184977185, not_class_recall 0.948551959114, not_class_F1 0.96265560166
# 		MacroF1Mesure 0.968322020483
# threshold 0.211
# 	class_prec 0.964226091104, class_recall 0.983937697737, class_F1 0.97398217297
# 	not_class_prec 0.97685022799, not_class_recall 0.948892674617, not_class_F1 0.962668510197
# 		MacroF1Mesure 0.968325341584
# threshold 0.212
# 	class_prec 0.964686232403, class_recall 0.983937697737, class_F1 0.97421686747
# 	not_class_prec 0.976866456362, not_class_recall 0.949574105622, not_class_F1 0.963026952315
# 		MacroF1Mesure 0.968621909893
# threshold 0.213
# 	class_prec 0.964686232403, class_recall 0.983937697737, class_F1 0.97421686747
# 	not_class_prec 0.976866456362, not_class_recall 0.949574105622, not_class_F1 0.963026952315
# 		MacroF1Mesure 0.968621909893
# threshold 0.214
# 	class_prec 0.964908092624, class_recall 0.983694329521, class_F1 0.974210653169
# 	not_class_prec 0.976532399299, not_class_recall 0.949914821124, not_class_F1 0.963039723661
# 		MacroF1Mesure 0.968625188415
# threshold 0.215
# 	class_prec 0.965138490926, class_recall 0.983694329521, class_F1 0.974328070387
# 	not_class_prec 0.976540616246, not_class_recall 0.950255536627, not_class_F1 0.963218787774
# 		MacroF1Mesure 0.968773429081
# threshold 0.216
# ...
# 	class_prec 0.994736842105, class_recall 0.919931856899, class_F1 0.955873056012
# 	not_class_prec 0.898581997534, not_class_recall 0.993185689949, not_class_F1 0.943518368668
# 		MacroF1Mesure 0.94969571234
# threshold 0.928
# 	class_prec 0.994735456699, class_recall 0.919688488683, class_F1 0.95574102175
# 	not_class_prec 0.898305084746, not_class_recall 0.993185689949, not_class_F1 0.943365695793
# 		MacroF1Mesure 0.949553358772
# threshold 0.929
# 	class_prec 0.995259415328, class_recall 0.919688488683, class_F1 0.955982797875
# 	not_class_prec 0.898367724053, not_class_recall 0.993867120954, not_class_F1 0.943707538014
# 		MacroF1Mesure 0.949845167944
# threshold 0.93
# 	class_prec 0.995255666842, class_recall 0.918958384035, class_F1 0.955586486145
# 	not_class_prec 0.897538461538, not_class_recall 0.993867120954, not_class_F1 0.943249797898
# 		MacroF1Mesure 0.949418142021
# threshold 0.931
# 	class_prec 0.995255666842, class_recall 0.918958384035, class_F1 0.955586486145
# 	not_class_prec 0.897538461538, not_class_recall 0.993867120954, not_class_F1 0.943249797898
# 		MacroF1Mesure 0.949418142021
# threshold 0.932
# 	class_prec 0.995255666842, class_recall 0.918958384035, class_F1 0.955586486145
# 	not_class_prec 0.897538461538, not_class_recall 0.993867120954, not_class_F1 0.943249797898
# 		MacroF1Mesure 0.949418142021
# threshold 0.933
# 	class_prec 0.995249406176, class_recall 0.917741542954, class_F1 0.954925297544
# 	not_class_prec 0.896159754224, not_class_recall 0.993867120954, not_class_F1 0.942487883683
# 		MacroF1Mesure 0.948706590614
# threshold 0.934
# 	class_prec 0.995249406176, class_recall 0.917741542954, class_F1 0.954925297544
# 	not_class_prec 0.896159754224, not_class_recall 0.993867120954, not_class_F1 0.942487883683
# 		MacroF1Mesure 0.948706590614
# threshold 0.935
# 	class_prec 0.99524689728, class_recall 0.917254806522, class_F1 0.954660587639
# 	not_class_prec 0.895609456555, not_class_recall 0.993867120954, not_class_F1 0.942183462532
# 		MacroF1Mesure 0.948422025086
# threshold 0.936
# 	class_prec 0.995241871531, class_recall 0.916281333658, class_F1 0.954130765332
# 	not_class_prec 0.894510886231, not_class_recall 0.993867120954, not_class_F1 0.941575209813
# 		MacroF1Mesure 0.947852987572
# threshold 0.937
# 	class_prec 0.995240613432, class_recall 0.916037965442, class_F1 0.953998225827
# 	not_class_prec 0.894236664623, not_class_recall 0.993867120954, not_class_F1 0.941423269324
# 		MacroF1Mesure 0.947710747575
# threshold 0.938
# 	class_prec 0.995238095238, class_recall 0.915551229009, class_F1 0.953733046013
# 	not_class_prec 0.89368872549, not_class_recall 0.993867120954, not_class_F1 0.941119535409
# 		MacroF1Mesure 0.947426290711
# threshold 0.939
# 	class_prec 0.995236835142, class_recall 0.915307860793, class_F1 0.95360040568
# 	not_class_prec 0.893415007657, not_class_recall 0.993867120954, not_class_F1 0.940967741935
# 		MacroF1Mesure 0.947284073807
# threshold 0.94
# 	class_prec 0.99549191196, class_recall 0.913604283281, class_F1 0.952791878173
# 	not_class_prec 0.891536816376, not_class_recall 0.994207836457, not_class_F1 0.940077319588
# 		MacroF1Mesure 0.94643459888
# threshold 0.941
# 	class_prec 0.995489519767, class_recall 0.913117546848, class_F1 0.952526021833
# 	not_class_prec 0.890992366412, not_class_recall 0.994207836457, not_class_F1 0.939774557166
# 		MacroF1Mesure 0.946150289499
# threshold 0.942
# 	class_prec 0.995488322718, class_recall 0.912874178632, class_F1 0.952393043037
# 	not_class_prec 0.89072039072, not_class_recall 0.994207836457, not_class_F1 0.939623249074
# 		MacroF1Mesure 0.946008146055
# threshold 0.943
# 	class_prec 0.995484727756, class_recall 0.912144073984, class_F1 0.951993903988
# 	not_class_prec 0.889905458981, not_class_recall 0.994207836457, not_class_F1 0.939169616994
# 		MacroF1Mesure 0.945581760491
# threshold 0.944
# 	class_prec 0.995483528162, class_recall 0.911900705768, class_F1 0.951860790042
# 	not_class_prec 0.889634146341, not_class_recall 0.994207836457, not_class_F1 0.93901850362
# 		MacroF1Mesure 0.945439646831
# threshold 0.945
# 	class_prec 0.995746943115, class_recall 0.911657337552, class_F1 0.951848557998
# 	not_class_prec 0.889396709324, not_class_recall 0.994548551959, not_class_F1 0.93903812128
# 		MacroF1Mesure 0.945443339639
# threshold 0.946
# 	class_prec 0.995736743938, class_recall 0.909467023607, class_F1 0.950648689901
# 	not_class_prec 0.886964448496, not_class_recall 0.994548551959, not_class_F1 0.937680693864
# 		MacroF1Mesure 0.944164691883
# threshold 0.947
# 	class_prec 0.995715050884, class_recall 0.904843027501, class_F1 0.948106591865
# 	not_class_prec 0.881873111782, not_class_recall 0.994548551959, not_class_F1 0.93482786229
# 		MacroF1Mesure 0.941467227078
# threshold 0.948
# 	class_prec 0.995712754555, class_recall 0.904356291068, class_F1 0.947838285933
# 	not_class_prec 0.88134057971, not_class_recall 0.994548551959, not_class_F1 0.934528573715
# 		MacroF1Mesure 0.941183429824
# threshold 0.949
# 	class_prec 0.995709305444, class_recall 0.90362618642, class_F1 0.947435570299
# 	not_class_prec 0.880542986425, not_class_recall 0.994548551959, not_class_F1 0.93408
# 		MacroF1Mesure 0.940757785149
# threshold 0.95
# 	class_prec 0.995704697987, class_recall 0.902652713556, class_F1 0.946898136329
# 	not_class_prec 0.879481771618, not_class_recall 0.994548551959, not_class_F1 0.933482571154
# 		MacroF1Mesure 0.940190353742
# threshold 0.951
# 	class_prec 0.99596448749, class_recall 0.900949136043, class_F1 0.946077178635
# 	not_class_prec 0.87766756838, not_class_recall 0.994889267462, not_class_F1 0.932609389971
# 		MacroF1Mesure 0.939343284303
# threshold 0.952
# 	class_prec 0.996226415094, class_recall 0.899488926746, class_F1 0.945389435989
# 	not_class_prec 0.876124775045, not_class_recall 0.995229982964, not_class_F1 0.931887063327
# 		MacroF1Mesure 0.938638249658
# threshold 0.953
# 	class_prec 0.996223361209, class_recall 0.898758822098, class_F1 0.944984646878
# 	not_class_prec 0.875337129158, not_class_recall 0.995229982964, not_class_F1 0.931441326531
# 		MacroF1Mesure 0.938212986704
# threshold 0.954
# 	class_prec 0.996212121212, class_recall 0.896081771721, class_F1 0.943497757848
# 	not_class_prec 0.872461170848, not_class_recall 0.995229982964, not_class_F1 0.929810600032
# 		MacroF1Mesure 0.93665417894
# threshold 0.955
# 	class_prec 0.996210070384, class_recall 0.895595035288, class_F1 0.943226963988
# 	not_class_prec 0.871940298507, not_class_recall 0.995229982964, not_class_F1 0.929514717582
# 		MacroF1Mesure 0.936370840785
# threshold 0.956
# 	class_prec 0.996202874966, class_recall 0.893891457776, class_F1 0.942278091329
# 	not_class_prec 0.870122132857, not_class_recall 0.995229982964, not_class_F1 0.928480610299
# 		MacroF1Mesure 0.935379350814
# threshold 0.957
# 	class_prec 0.996192548273, class_recall 0.891457775615, class_F1 0.940919599281
# 	not_class_prec 0.867537867538, not_class_recall 0.995229982964, not_class_F1 0.92700729927
# 		MacroF1Mesure 0.933963449275
# threshold 0.958
# 	class_prec 0.996447116699, class_recall 0.887320515941, class_F1 0.938722966014
# 	not_class_prec 0.863220088626, not_class_recall 0.995570698467, not_class_F1 0.924683544304
# 		MacroF1Mesure 0.931703255159
# threshold 0.959
# 	class_prec 0.996424642464, class_recall 0.88172304697, class_F1 0.935571336346
# 	not_class_prec 0.857394366197, not_class_recall 0.995570698467, not_class_F1 0.921330600662
# 		MacroF1Mesure 0.928450968504
# threshold 0.96
# 	class_prec 0.996415770609, class_recall 0.879532733025, class_F1 0.934332988625
# 	not_class_prec 0.855136084284, not_class_recall 0.995570698467, not_class_F1 0.920025188917
# 		MacroF1Mesure 0.927179088771
# threshold 0.961
# 	class_prec 0.996400885936, class_recall 0.875882209783, class_F1 0.932262660277
# 	not_class_prec 0.851398601399, not_class_recall 0.995570698467, not_class_F1 0.917857703785
# 		MacroF1Mesure 0.925060182031
# threshold 0.962
# 	class_prec 0.996943595443, class_recall 0.873205159406, class_F1 0.93098079917
# 	not_class_prec 0.848766328012, not_class_recall 0.996252129472, not_class_F1 0.916614420063
# 		MacroF1Mesure 0.923797609616
# threshold 0.963
# 	class_prec 0.996917040359, class_recall 0.865660744707, class_F1 0.926664061482
# 	not_class_prec 0.841196777906, not_class_recall 0.996252129472, not_class_F1 0.912182186866
# 		MacroF1Mesure 0.919423124174
# threshold 0.964
# 	class_prec 0.99690663667, class_recall 0.862740326113, class_F1 0.924983692107
# 	not_class_prec 0.838302752294, not_class_recall 0.996252129472, not_class_F1 0.910477969796
# 		MacroF1Mesure 0.917730830952
# threshold 0.965
# 	class_prec 0.997461212976, class_recall 0.860550012168, class_F1 0.923961327411
# 	not_class_prec 0.836238925407, not_class_recall 0.996933560477, not_class_F1 0.909543052533
# 		MacroF1Mesure 0.916752189972
# threshold 0.966
# 	class_prec 0.997445359069, class_recall 0.855195911414, class_F1 0.920859538784
# 	not_class_prec 0.831013916501, not_class_recall 0.996933560477, not_class_F1 0.90644361834
# 		MacroF1Mesure 0.913651578562
# threshold 0.967
# 	class_prec 0.997714285714, class_recall 0.84984181066, class_F1 0.91786042844
# 	not_class_prec 0.825902934537, not_class_recall 0.99727427598, not_class_F1 0.903534496064
# 		MacroF1Mesure 0.910697462252
# threshold 0.968
# 	class_prec 0.997705764267, class_recall 0.84667802385, class_F1 0.916008425487
# 	not_class_prec 0.822884453191, not_class_recall 0.99727427598, not_class_F1 0.901725200246
# 		MacroF1Mesure 0.908866812867
# threshold 0.969
# 	class_prec 0.997695188706, class_recall 0.842784132392, class_F1 0.913720316623
# 	not_class_prec 0.819199552197, not_class_recall 0.99727427598, not_class_F1 0.89950829748
# 		MacroF1Mesure 0.906614307051
# threshold 0.97
# 	class_prec 0.997972190035, class_recall 0.838403504502, class_F1 0.911255124983
# 	not_class_prec 0.815144766147, not_class_recall 0.997614991482, not_class_F1 0.897196261682
# 		MacroF1Mesure 0.904225693333
# threshold 0.971
# 	class_prec 0.998248175182, class_recall 0.832075930883, class_F1 0.907618794797
# 	not_class_prec 0.809339596574, not_class_recall 0.997955706985, not_class_F1 0.893805309735
# 		MacroF1Mesure 0.900712052266
# threshold 0.972
# 	class_prec 0.998236849838, class_recall 0.826721830129, class_F1 0.904419595314
# 	not_class_prec 0.804449327108, not_class_recall 0.997955706985, not_class_F1 0.890815085158
# 		MacroF1Mesure 0.897617340236
# threshold 0.973
# 	class_prec 0.998228520815, class_recall 0.822827938671, class_F1 0.902081109925
# 	not_class_prec 0.800929723817, not_class_recall 0.997955706985, not_class_F1 0.888652912621
# 		MacroF1Mesure 0.895367011273
# threshold 0.974
# 	class_prec 0.99821215733, class_recall 0.815283523972, class_F1 0.897521768252
# 	not_class_prec 0.794197396963, not_class_recall 0.997955706985, not_class_F1 0.884493431979
# 		MacroF1Mesure 0.891007600116
# threshold 0.975
# 	class_prec 0.998796992481, class_recall 0.808225845705, class_F1 0.893462469734
# 	not_class_prec 0.7881150847, not_class_recall 0.99863713799, not_class_F1 0.880973850316
# 		MacroF1Mesure 0.887218160025
# threshold 0.976
# 	class_prec 0.998782714547, class_recall 0.798734485276, class_F1 0.887626774848
# 	not_class_prec 0.779936136243, not_class_recall 0.99863713799, not_class_F1 0.8758404303
# 		MacroF1Mesure 0.881733602574
# threshold 0.977
# 	class_prec 0.99876771411, class_recall 0.788999756632, class_F1 0.881577158396
# 	not_class_prec 0.771721958926, not_class_recall 0.99863713799, not_class_F1 0.870637160255
# 		MacroF1Mesure 0.876107159326
# threshold 0.978
# 	class_prec 0.998748043818, class_recall 0.77658797761, class_F1 0.873767798467
# 	not_class_prec 0.761496492595, not_class_recall 0.99863713799, not_class_F1 0.864091981132
# 		MacroF1Mesure 0.868929889799
# threshold 0.979
# 	class_prec 0.998732171157, class_recall 0.766853248966, class_F1 0.867566079295
# 	not_class_prec 0.753664181023, not_class_recall 0.99863713799, not_class_F1 0.859026963658
# 		MacroF1Mesure 0.863296521476
# threshold 0.98
# 	class_prec 0.999032258065, class_recall 0.753711365296, class_F1 0.859203773061
# 	not_class_prec 0.743407707911, not_class_recall 0.998977853492, not_class_F1 0.852449483937
# 		MacroF1Mesure 0.855826628499
# threshold 0.981
# 	class_prec 0.999343832021, class_recall 0.741299586274, class_F1 0.851194634623
# 	not_class_prec 0.733983983984, not_class_recall 0.999318568995, not_class_F1 0.846342519117
# 		MacroF1Mesure 0.84876857687
# threshold 0.982
# 	class_prec 0.999336650083, class_recall 0.733268435142, class_F1 0.845873104997
# 	not_class_prec 0.727972201539, not_class_recall 0.999318568995, not_class_F1 0.842331993107
# 		MacroF1Mesure 0.844102549052
# threshold 0.983
# 	class_prec 0.999325236167, class_recall 0.720856656121, class_F1 0.837551251237
# 	not_class_prec 0.71887254902, not_class_recall 0.999318568995, not_class_F1 0.836208125445
# 		MacroF1Mesure 0.836879688341
# threshold 0.984
# 	class_prec 0.999315537303, class_recall 0.710635191044, class_F1 0.830607310482
# 	not_class_prec 0.711547792334, not_class_recall 0.999318568995, not_class_F1 0.831231401445
# 		MacroF1Mesure 0.830919355964
# threshold 0.985
# 	class_prec 0.999303135889, class_recall 0.697980043806, class_F1 0.821894254191
# 	not_class_prec 0.702683277432, not_class_recall 0.999318568995, not_class_F1 0.825151216767
# 		MacroF1Mesure 0.823522735479
# threshold 0.986
# 	class_prec 0.999292536258, class_recall 0.687515210514, class_F1 0.814590542099
# 	not_class_prec 0.695518140858, not_class_recall 0.999318568995, not_class_F1 0.8201901566
# 		MacroF1Mesure 0.817390349349
# threshold 0.987
# 	class_prec 0.999283410964, class_recall 0.678753954734, class_F1 0.808405797101
# 	not_class_prec 0.689630848813, not_class_recall 0.999318568995, not_class_F1 0.816082359488
# 		MacroF1Mesure 0.812244078295
# threshold 0.988
# 	class_prec 0.999265785609, class_recall 0.662448284254, class_F1 0.796721791307
# 	not_class_prec 0.678935185185, not_class_recall 0.999318568995, not_class_F1 0.808545830462
# 		MacroF1Mesure 0.802633810884
# threshold 0.989
# 	class_prec 0.999252895032, class_recall 0.651009978097, class_F1 0.788387857353
# 	not_class_prec 0.671628119991, not_class_recall 0.999318568995, not_class_F1 0.80334155026
# 		MacroF1Mesure 0.795864703807
# threshold 0.99
# 	class_prec 0.99924556771, class_recall 0.644682404478, class_F1 0.783727810651
# 	not_class_prec 0.667653084453, not_class_recall 0.999318568995, not_class_F1 0.800491266376
# 		MacroF1Mesure 0.792109538513
# threshold 0.991
# 	class_prec 0.99922809726, class_recall 0.630080311511, class_F1 0.772835820896
# 	not_class_prec 0.658657085111, not_class_recall 0.999318568995, not_class_F1 0.793990254467
# 		MacroF1Mesure 0.783413037681
# threshold 0.992
# 	class_prec 0.999605211212, class_recall 0.616208323193, class_F1 0.762420957543
# 	not_class_prec 0.650410108623, not_class_recall 0.999659284497, not_class_F1 0.788074133763
# 		MacroF1Mesure 0.775247545653
# threshold 0.993
# 	class_prec 0.99958315965, class_recall 0.583596982234, class_F1 0.736939151813
# 	not_class_prec 0.631646932185, not_class_recall 0.999659284497, not_class_F1 0.774142480211
# 		MacroF1Mesure 0.755540816012
# threshold 0.994
# 	class_prec 0.999540441176, class_recall 0.529325870041, class_F1 0.692124105012
# 	not_class_prec 0.602711585867, not_class_recall 0.999659284497, not_class_F1 0.752018454441
# 		MacroF1Mesure 0.722071279726
# threshold 0.995
# 	class_prec 0.999495713565, class_recall 0.482355804332, class_F1 0.650689428759
# 	not_class_prec 0.579727326615, not_class_recall 0.999659284497, not_class_F1 0.733866933467
# 		MacroF1Mesure 0.692278181113
# threshold 0.996
# 	class_prec 0.999047619048, class_recall 0.2552932587, class_F1 0.406667958907
# 	not_class_prec 0.489489489489, not_class_recall 0.999659284497, not_class_F1 0.657184455146
# 		MacroF1Mesure 0.531926207026
# threshold 0.997
# 	class_prec 1.0, class_recall 0.130445363835, class_F1 0.230785791173
# 	not_class_prec 0.45098340504, not_class_recall 1.0, not_class_F1 0.621624483745
# 		MacroF1Mesure 0.426205137459
# threshold 0.998
# 	class_prec 1.0, class_recall 0.03066439523, class_F1 0.0595041322314
# 	not_class_prec 0.424255565192, not_class_recall 1.0, not_class_F1 0.595757637268
# 		MacroF1Mesure 0.32763088475
# threshold 0.999
# 	class_prec 1.0, class_recall 0.000243368216111, class_F1 0.000486618004866
# 	not_class_prec 0.416725827062, not_class_recall 1.0, not_class_F1 0.588294247344
# 		MacroF1Mesure 0.294390432675

# %%
TEST_DATA_FILE  = 'kaggle/kaggle_test_data_tab.csv.gz'
# TEST_DATA_FILE  = 'kaggle/kaggle_train_data_tab_300.csv.gz'

test_docs = load_csv(TEST_DATA_FILE, calc_features)

# %%
prediction = classifier.predict_all(test_docs)
# Out:
# 11:16:52 INFO:Complete items 00000
# 11:16:52 INFO:Complete items 00000
# 11:16:52 INFO:Complete items 00000
# 11:16:52 INFO:Complete items 00000
# 11:17:25 INFO:Complete items 01000
# 11:17:25 INFO:Complete items 01000
# 11:17:25 INFO:Complete items 01000
# 11:17:25 INFO:Complete items 01000
# 11:17:53 INFO:Complete items 02000
# 11:17:53 INFO:Complete items 02000
# 11:17:53 INFO:Complete items 02000
# 11:17:53 INFO:Complete items 02000
# 11:18:20 INFO:Complete items 03000
# 11:18:20 INFO:Complete items 03000
# 11:18:20 INFO:Complete items 03000
# 11:18:20 INFO:Complete items 03000
# 11:18:44 INFO:Complete items 04000
# 11:18:44 INFO:Complete items 04000
# 11:18:44 INFO:Complete items 04000
# 11:18:44 INFO:Complete items 04000
# 11:19:06 INFO:Complete items 05000
# 11:19:06 INFO:Complete items 05000
# 11:19:06 INFO:Complete items 05000
# 11:19:06 INFO:Complete items 05000
# 11:19:34 INFO:Complete items 06000
# 11:19:34 INFO:Complete items 06000
# 11:19:34 INFO:Complete items 06000
# 11:19:34 INFO:Complete items 06000
# 11:19:58 INFO:Complete items 07000
# 11:19:58 INFO:Complete items 07000
# 11:19:58 INFO:Complete items 07000
# 11:19:58 INFO:Complete items 07000
# 11:20:23 INFO:Complete items 08000
# 11:20:23 INFO:Complete items 08000
# 11:20:23 INFO:Complete items 08000
# 11:20:23 INFO:Complete items 08000
# 11:20:48 INFO:Complete items 09000
# 11:20:48 INFO:Complete items 09000
# 11:20:48 INFO:Complete items 09000
# 11:20:48 INFO:Complete items 09000
# 11:21:20 INFO:Complete items 10000
# 11:21:20 INFO:Complete items 10000
# 11:21:20 INFO:Complete items 10000
# 11:21:20 INFO:Complete items 10000
# 11:21:44 INFO:Complete items 11000
# 11:21:44 INFO:Complete items 11000
# 11:21:44 INFO:Complete items 11000
# 11:21:44 INFO:Complete items 11000
# 11:22:09 INFO:Complete items 12000
# 11:22:09 INFO:Complete items 12000
# 11:22:09 INFO:Complete items 12000
# 11:22:09 INFO:Complete items 12000
# 11:22:31 INFO:Complete items 13000
# 11:22:31 INFO:Complete items 13000
# 11:22:31 INFO:Complete items 13000
# 11:22:31 INFO:Complete items 13000
# 11:22:57 INFO:Complete items 14000
# 11:22:57 INFO:Complete items 14000
# 11:22:57 INFO:Complete items 14000
# 11:22:57 INFO:Complete items 14000
# 11:23:23 INFO:Complete items 15000
# 11:23:23 INFO:Complete items 15000
# 11:23:23 INFO:Complete items 15000
# 11:23:23 INFO:Complete items 15000
# 11:23:51 INFO:Complete items 16000
# 11:23:51 INFO:Complete items 16000
# 11:23:51 INFO:Complete items 16000
# 11:23:51 INFO:Complete items 16000
# 11:23:52 INFO:Complete items 16038

# %%
fout = open('my_submission.csv' , 'wb')
threshold = 0.5
try:
    writer = csv.writer(fout)
    writer.writerow(['Id','Prediction'])
    for item in prediction:
        p = 1 if item[3] > threshold else 0
        writer.writerow([item[0], p])
finally:
    fout.close()
